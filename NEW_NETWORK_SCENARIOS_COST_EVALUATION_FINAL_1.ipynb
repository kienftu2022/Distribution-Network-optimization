# %% [markdown]
# # Import necessary libraries

# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import math
from math import radians, sin, cos, sqrt, atan2
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ---
# # Current baseline parameters

# %%
lat_ref = -29.79165152  # Current DC latitude
lon_ref = 151.1250996   # Current DC longitude
avg_inv_cbm_curr = 14898  # Current inventory CBM
storage_cost_cbm_curr = 30  # Current storage cost per CBM
handling_cost_cbm_curr = 10  # Current handling cost per CBM
TRUCK_CAPACITY = 20000  # 20 tons truck capacity (Standard Australian heavy truck)

# %% [markdown]
# ---
# Connect to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ---
# ## df_shipto_master

# %%
print("\n📊Preparing data for clustering...")

file_path_shipto_master = "/content/drive/MyDrive/0027. CUỘC THI/01. LOGAGE 2025/02. VÒNG 2/PROJECT/02. IMPLEMENTATION/03. New distribution network design/processed_shipto_master.csv"

df_shipto_master = pd.read_csv(file_path_shipto_master)
# Out:
# 📊Preparing data for clustering...

# %%
display(df_shipto_master.head(3))
# Out:
#   ShipToID   Longitude   Latitude            State         City  \
# 0   3001BR  151.001259 -33.797556  New South Wales   Parramatta
# 1   3002BR  149.206300 -35.347000  New South Wales   Queanbeyan
# 2   3003BR  147.343011 -35.122016  New South Wales  Wagga Wagga
#
#              Suburb  Annual_CBM_Demand_ShipTo  Annual_KG_Demand_ShipTo  \
# 0  North Parramatta                 91.182518               11801.9360
# 1        Queanbeyan                100.414742               12320.3690
# 2       Wagga Wagga                882.881842               99185.9602
#
#    Total_Shipments
# 0              313
# 1              314
# 2              694

# %% [markdown]
# ---
# # Divided into 5 phases for delivery

# %%
# Chia 5 xuống
df_shipto_master['Annual_KG_Demand_ShipTo'] = df_shipto_master['Annual_KG_Demand_ShipTo'] / 5
df_shipto_master['Annual_CBM_Demand_ShipTo'] = df_shipto_master['Annual_CBM_Demand_ShipTo'] / 5
df_shipto_master['Total_Shipments'] = df_shipto_master['Total_Shipments'] / 5

# %%
# Enhanced KG to CBM conversion ratio
if 'Annual_CBM_Demand_ShipTo' in df_shipto_master.columns:
    total_kg = df_shipto_master['Annual_KG_Demand_ShipTo'].sum()
    total_cbm = df_shipto_master['Annual_CBM_Demand_ShipTo'].sum()
    ACTUAL_KG_PER_CBM = total_kg / total_cbm if total_cbm > 0 else 167
    print(f"✅ Using actual KG/CBM ratio from data: {ACTUAL_KG_PER_CBM:.1f} kg/CBM")
else:
    ACTUAL_KG_PER_CBM = 167  # Realistic for Australian freight
    print(f"📊 Using industry standard KG/CBM ratio: {ACTUAL_KG_PER_CBM} kg/CBM")

# Enhanced cost adjustment factors
URBAN_ADJUSTMENT_FACTOR = 1.1  # Urban areas 10% higher costs
RURAL_ADJUSTMENT_FACTOR = 0.7  # Rural areas 30% lower costs
# Out:
# ✅ Using actual KG/CBM ratio from data: 143.6 kg/CBM

# %% [markdown]
# ---
# ## cost curve data

# %%
file_path_cost_curve = '/content/drive/MyDrive/0027. CUỘC THI/01. LOGAGE 2025/02. VÒNG 2/PROJECT/01. DATASET/LOGage2025_Round 2_Data.xlsx_CostCurve.csv'

costcurve = pd.read_csv(file_path_cost_curve)

display(costcurve)
# Out:
#                State Mode Intercept (AUD) Slope (AUD/KM)  Min Distance (KM)  \
# 0    New South Wales  FTL           225,2            0,9                  0
# 1    New South Wales  LTL           360,4            1,1                 55
# 2         Queensland  FTL           192,6            0,2                  0
# 3         Queensland  LTL           226,7            0,3                100
# 4           Victoria  FTL           198,4              1                  0
# 5           Victoria  LTL           334,8            0,2                 70
# 6  Western Australia  FTL            95,8            1,2                  0
# 7  Western Australia  LTL           242,2            0,5                 55
#
#    Max Distance (KM)
# 0                 55
# 1             999999
# 2                100
# 3             999999
# 4                 70
# 5             999999
# 6                 55
# 7             999999

# %%
print(f"🏢 Current DC: ({lon_ref}, {lat_ref})")
print(f"🚛 Truck capacity: {TRUCK_CAPACITY:,} KG (Standard heavy truck capacity in Australia)")
print(f"📦 Current inventory: {avg_inv_cbm_curr:,} CBM")
print(f"⚖️ KG to CBM ratio: {ACTUAL_KG_PER_CBM} kg/CBM (Industry standard assumption)")
baseline_total_cost =  3078427
print(f"💰 Baseline total cost: ${baseline_total_cost:,.0f}")
# Out:
# 🏢 Current DC: (151.1250996, -29.79165152)
# 🚛 Truck capacity: 20,000 KG (Standard heavy truck capacity in Australia)
# 📦 Current inventory: 14,898 CBM
# ⚖️ KG to CBM ratio: 143.64973855978565 kg/CBM (Industry standard assumption)
# 💰 Baseline total cost: $3,078,427

# %% [markdown]
# ---
# # Function

# %%
def lookup_cost_enhanced(state, distance, costcurve):
    """Enhanced cost curve lookup with if-else logic for better accuracy"""
    try:
        # Clean and standardize state name
        state_clean = state.strip().upper()

        # Handle different state variations and apply cost curves
        if state_clean in ['NEW SOUTH WALES', 'NSW']:
            if distance <= 55:
                return 225.2, 0.9, 'FTL'
            else:
                return 360.4, 1.1, 'LTL'

        elif state_clean in ['QUEENSLAND', 'QLD']:
            if distance <= 100:
                return 192.6, 0.2, 'FTL'
            else:
                return 226.7, 0.3, 'LTL'

        elif state_clean in ['VICTORIA', 'VIC']:
            if distance <= 70:
                return 198.4, 1.0, 'FTL'
            else:
                return 334.8, 0.2, 'LTL'

        elif state_clean in ['WESTERN AUSTRALIA', 'WA']:
            if distance <= 55:
                return 95.8, 1.2, 'FTL'
            else:
                return 242.2, 0.5, 'LTL'

        # Handle other Australian states with fallback to NSW
        elif state_clean in ['SOUTH AUSTRALIA', 'SA', 'TASMANIA', 'TAS', 'NORTHERN TERRITORY', 'NT', 'AUSTRALIAN CAPITAL TERRITORY', 'ACT']:
            print(f"⚠️ Using NSW fallback for {state}")
            if distance <= 55:
                return 225.2, 0.9, 'FTL'
            else:
                return 360.4, 1.1, 'LTL'

        # Try partial matching for state names
        else:
            # Extract first word for partial matching
            first_word = state.split()[0].upper() if state.split() else state_clean

            if 'NEW' in first_word or 'SOUTH' in state_clean.split():
                if distance <= 55:
                    return 225.2, 0.9, 'FTL'
                else:
                    return 360.4, 1.1, 'LTL'

            elif 'QUEEN' in first_word:
                if distance <= 100:
                    return 192.6, 0.2, 'FTL'
                else:
                    return 226.7, 0.3, 'LTL'

            elif 'VICT' in first_word:
                if distance <= 70:
                    return 198.4, 1.0, 'FTL'
                else:
                    return 334.8, 0.2, 'LTL'

            elif 'WEST' in first_word:
                if distance <= 55:
                    return 95.8, 1.2, 'FTL'
                else:
                    return 242.2, 0.5, 'LTL'

            # Ultimate fallback to NSW LTL
            else:
                print(f"⚠️ Using NSW LTL fallback for unrecognized state: {state}")
                return 360.4, 1.1, 'LTL'

    except Exception as e:
        print(f"⚠️ Critical error in cost lookup for {state}: {e}")
        # Ultimate fallback to NSW LTL
        return 360.4, 1.1, 'LTL'

def enhanced_truck_consolidation(rdc_shiptos, rdc_id, TRUCK_CAPACITY):
    """Enhanced truck consolidation algorithm with better bin packing"""
    if len(rdc_shiptos) == 0:
        return []

    # Sort by demand in descending order for better bin packing (First Fit Decreasing)
    remaining_shiptos = rdc_shiptos.copy().sort_values('Annual_KG_Demand_ShipTo', ascending=False).reset_index(drop=True)
    trucks = []
    truck_counter = 0

    while len(remaining_shiptos) > 0:
        # Create new truck
        truck_shiptos = []
        current_weight = 0
        indices_to_remove = []

        # Try to fit shipments into current truck using First Fit Decreasing
        for idx, row in remaining_shiptos.iterrows():
            shipment_weight = row['Annual_KG_Demand_ShipTo']

            # Skip if shipment weight is 0 or negative
            if shipment_weight <= 0:
                indices_to_remove.append(idx)
                continue

            # If shipment fits completely in truck
            if current_weight + shipment_weight <= TRUCK_CAPACITY:
                truck_shiptos.append({
                    'ShipToID': row['ShipToID'],
                    'Longitude': row['Longitude'],
                    'Latitude': row['Latitude'],
                    'Annual_KG_Demand_ShipTo': shipment_weight
                })
                current_weight += shipment_weight
                indices_to_remove.append(idx)

            # If shipment is larger than remaining capacity but truck has space
            elif shipment_weight > TRUCK_CAPACITY and current_weight < TRUCK_CAPACITY:
                # Split the shipment: take what fits in current truck
                remaining_capacity = TRUCK_CAPACITY - current_weight
                if remaining_capacity > 0:
                    truck_shiptos.append({
                        'ShipToID': f"{row['ShipToID']}_split_{truck_counter}",
                        'Longitude': row['Longitude'],
                        'Latitude': row['Latitude'],
                        'Annual_KG_Demand_ShipTo': remaining_capacity
                    })
                    current_weight += remaining_capacity

                    # Reduce the original shipment weight
                    remaining_shiptos.loc[idx, 'Annual_KG_Demand_ShipTo'] -= remaining_capacity
                break  # Truck is now full

            # If single shipment exceeds truck capacity and truck is empty
            elif shipment_weight > TRUCK_CAPACITY and current_weight == 0:
                # Create dedicated truck for this oversized shipment
                truck_shiptos.append({
                    'ShipToID': f"{row['ShipToID']}_oversized_{truck_counter}",
                    'Longitude': row['Longitude'],
                    'Latitude': row['Latitude'],
                    'Annual_KG_Demand_ShipTo': min(shipment_weight, TRUCK_CAPACITY)
                })
                current_weight = min(shipment_weight, TRUCK_CAPACITY)

                # If shipment is larger than truck capacity, reduce it
                if shipment_weight > TRUCK_CAPACITY:
                    remaining_shiptos.loc[idx, 'Annual_KG_Demand_ShipTo'] -= TRUCK_CAPACITY
                else:
                    indices_to_remove.append(idx)
                break  # Move to next truck

        # Only create truck if it has shipments
        if truck_shiptos:
            trucks.append({
                'truck_id': truck_counter,
                'shiptos': truck_shiptos,
                'total_weight': current_weight,
                'rdc_id': rdc_id,
                'capacity_utilization': (current_weight / TRUCK_CAPACITY) * 100
            })
            truck_counter += 1

        # Remove processed shipments
        if indices_to_remove:
            remaining_shiptos = remaining_shiptos.drop(indices_to_remove).reset_index(drop=True)
        else:
            # Prevent infinite loop
            if len(remaining_shiptos) > 0:
                print(f"⚠️ Removing problematic shipment: {remaining_shiptos.iloc[0]['ShipToID']}")
                remaining_shiptos = remaining_shiptos.drop(0).reset_index(drop=True)

    return trucks

def nearest_neighbor_tsp(dist_matrix, start=0):
    """Nearest Neighbor TSP heuristic"""
    n = len(dist_matrix)
    unvisited = set(range(n))
    unvisited.remove(start)

    route = [start]
    current = start

    while unvisited:
        nearest = min(unvisited, key=lambda x: dist_matrix[current][x])
        route.append(nearest)
        unvisited.remove(nearest)
        current = nearest

    # Return to start
    route.append(start)
    return route

def farthest_insertion_tsp(dist_matrix, start=0):
    """Farthest Insertion TSP heuristic"""
    n = len(dist_matrix)

    # Start with the two farthest points from start
    unvisited = set(range(1, n))  # Exclude start point
    farthest = max(unvisited, key=lambda x: dist_matrix[start][x])

    route = [start, farthest, start]
    unvisited.remove(farthest)

    while unvisited:
        # Find the unvisited city farthest from the current route
        farthest_city = None
        max_min_distance = -1

        for city in unvisited:
            min_distance_to_route = min(dist_matrix[city][route_city] for route_city in route[:-1])
            if min_distance_to_route > max_min_distance:
                max_min_distance = min_distance_to_route
                farthest_city = city

        # Find the best position to insert the farthest city
        best_position = 1
        best_increase = float('inf')

        for i in range(1, len(route)):
            prev_city = route[i-1]
            next_city = route[i]

            increase = (dist_matrix[prev_city][farthest_city] +
                       dist_matrix[farthest_city][next_city] -
                       dist_matrix[prev_city][next_city])

            if increase < best_increase:
                best_increase = increase
                best_position = i

        # Insert the city at the best position
        route.insert(best_position, farthest_city)
        unvisited.remove(farthest_city)

    return route

def calculate_route_distance(route, dist_matrix):
    """Calculate total distance for a given route"""
    total_distance = 0
    for i in range(len(route) - 2):
        total_distance += dist_matrix[route[i]][route[i + 1]]
    return total_distance

def enhanced_tsp_solver(locations, dist_matrix):
    """Enhanced TSP solver with multiple heuristics"""
    n_locations = len(locations)

    if n_locations <= 1:
        return 0.0, [0] if n_locations == 1 else []

    if n_locations == 2:
        # Simple round trip for 2 locations
        return dist_matrix[0][1] * 2, [0, 1, 0]

    # Try multiple heuristics and pick the best
    best_distance = float('inf')
    best_route = None

    # Heuristic 1: Nearest Neighbor starting from depot (RDC)
    route_nn = nearest_neighbor_tsp(dist_matrix, start=0)
    distance_nn = calculate_route_distance(route_nn, dist_matrix)

    if distance_nn < best_distance:
        best_distance = distance_nn
        best_route = route_nn

    # Heuristic 2: Farthest Insertion (for larger problems)
    if n_locations > 5:
        try:
            route_fi = farthest_insertion_tsp(dist_matrix, start=0)
            distance_fi = calculate_route_distance(route_fi, dist_matrix)

            if distance_fi < best_distance:
                best_distance = distance_fi
                best_route = route_fi
        except:
            pass  # Fall back to nearest neighbor if farthest insertion fails

    return best_distance, best_route

def haversine_distance_vectorized(lat1, lon1, lat2, lon2):
    """Optimized Haversine distance calculation"""
    R = 6371  # Earth radius in km
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    dlat, dlon = lat2 - lat1, lon2 - lon1
    a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))
    return R * c

def get_state_enhanced(lat, lon):
    """Enhanced state determination with geopy and improved fallback"""
    try:
        from geopy.geocoders import Nominatim
        geolocator = Nominatim(user_agent="supply_chain_opt_final", timeout=5)
        location = geolocator.reverse(f"{lat}, {lon}", exactly_one=True)
        if location and location.raw.get('address'):
            address = location.raw['address']
            for key in ['state', 'administrative_area_level_1', 'province']:
                if key in address and address[key]:
                    state = address[key]
                    print(f"✅ Geopy: {state} for ({lat:.3f}, {lon:.3f})")
                    return state
    except:
        pass

    # Enhanced Australian state boundaries fallback
    if lat > -11:
        return "Northern Territory"
    elif lat > -25 and lon > 148:
        return "Queensland"
    elif lat > -29 and lon > 147:
        return "New South Wales"
    elif lat > -34 and lon > 143 and lon < 150:
        return "Victoria"
    elif lon < 130:
        return "Western Australia"
    elif lon < 143:
        return "South Australia"
    else:
        return "Tasmania"

def classify_location_type(lat, lon, state):
    """Enhanced urban/rural classification"""
    major_metros = {
        'New South Wales': [(-33.8688, 151.2093, 60), (-32.9267, 151.7767, 25)],
        'Victoria': [(-37.8136, 144.9631, 50), (-38.1478, 144.3606, 20)],
        'Queensland': [(-27.4698, 153.0251, 50), (-16.9186, 145.7781, 20)],
        'Western Australia': [(-31.9505, 115.8605, 40)],
        'South Australia': [(-34.9285, 138.6007, 30)],
        'Tasmania': [(-42.8821, 147.3272, 20)],
        'Northern Territory': [(-12.4634, 130.8456, 25)]
    }

    if state in major_metros:
        for city_lat, city_lon, radius in major_metros[state]:
            distance = haversine_distance_vectorized(lat, lon, city_lat, city_lon)
            if distance < radius:
                return "Urban"
    return "Rural"

# %% [markdown]
# ---
# # DATA PREPROCESSING WITH STANDARDIZATION

# %%
print(f"\n📊 STEP 0: Data Preprocessing and Standardization...")

# Prepare features for K-means clustering
X_features = df_shipto_master[['Longitude', 'Latitude']].values
print(f"📍 Original coordinate ranges:")
print(f"   Longitude: [{X_features[:, 0].min():.3f}, {X_features[:, 0].max():.3f}]")
print(f"   Latitude: [{X_features[:, 1].min():.3f}, {X_features[:, 1].max():.3f}]")

# Apply StandardScaler for proper K-means clustering
scaler = StandardScaler()
X_normalized = scaler.fit_transform(X_features)
print(f"✅ Data standardized using StandardScaler")
# Out:
# 📊 STEP 0: Data Preprocessing and Standardization...
# 📍 Original coordinate ranges:
#    Longitude: [114.627, 153.579]
#    Latitude: [-42.973, -12.402]
# ✅ Data standardized using StandardScaler

# %% [markdown]
# ---
# # SCENARIO CONFIGURATIONS

# %%
K_scenarios = [2, 3, 4, 5, 6, 7, 8]
print(f"🎯 Evaluating K scenarios: {K_scenarios}")

all_scenario_results = {}

# ========================================================================================
# MAIN SCENARIO EVALUATION LOOP
# ========================================================================================

for K in K_scenarios:
    print(f"\n" + "="*60)
    print(f"🎯 EVALUATING SCENARIO K = {K} RDCs")
    print("="*60)

    # ========================================================================================
    # STEP 1: STANDARDIZED K-MEANS CLUSTERING
    # ========================================================================================

    print(f"📍 Step 1: K-Means clustering with standardized data for K={K}...")

    # Apply K-Means on normalized data
    kmeans = KMeans(n_clusters=K, random_state=42, n_init=10, max_iter=300)
    cluster_labels = kmeans.fit_predict(X_normalized)

    # Transform centers back to original coordinate space
    rdc_centers_normalized = kmeans.cluster_centers_
    rdc_centers = scaler.inverse_transform(rdc_centers_normalized)

    # Add cluster assignment
    df_scenario = df_shipto_master.copy()
    df_scenario['RDC_Assignment'] = cluster_labels

    # Determine state and location type for each RDC
    rdc_states = []
    rdc_location_types = []

    print(f"✅ K-Means completed. Determining RDC characteristics...")
    for i, center in enumerate(rdc_centers):
        rdc_lon, rdc_lat = center
        rdc_state = get_state_enhanced(rdc_lat, rdc_lon)
        rdc_location_type = classify_location_type(rdc_lat, rdc_lon, rdc_state)

        rdc_states.append(rdc_state)
        rdc_location_types.append(rdc_location_type)

        cluster_data = df_scenario[df_scenario['RDC_Assignment'] == i]
        total_demand = cluster_data['Annual_KG_Demand_ShipTo'].sum()
        print(f"   RDC {i}: ({rdc_lon:.3f}, {rdc_lat:.3f}) - {rdc_state} ({rdc_location_type})")
        print(f"           Serves {len(cluster_data)} ShipToIDs, {total_demand:,.0f} KG")

    # ========================================================================================
    # STEP 2: BRANCH DELIVERY COSTS WITH ENHANCED CONSOLIDATION AND TSP
    # ========================================================================================

    print(f"\n🚛 Step 2: Branch Delivery Cost Calculation...")

    total_branch_delivery_cost = 0
    all_trucks_details = []

    for rdc_id in range(K):
        print(f"\n--- RDC {rdc_id} Analysis ({rdc_states[rdc_id]}) ---")

        rdc_shiptos = df_scenario[df_scenario['RDC_Assignment'] == rdc_id].copy()
        rdc_lon, rdc_lat = rdc_centers[rdc_id]
        rdc_state = rdc_states[rdc_id]

        if len(rdc_shiptos) == 0:
            continue

        print(f"🏢 RDC {rdc_id}: ({rdc_lon:.3f}, {rdc_lat:.3f}) in {rdc_state}")
        print(f"📦 Serves {len(rdc_shiptos)} ShipToIDs")
        print(f"⚖️ Total demand: {rdc_shiptos['Annual_KG_Demand_ShipTo'].sum():,.0f} KG")

        # ENHANCED: Use improved truck consolidation
        trucks = enhanced_truck_consolidation(rdc_shiptos, rdc_id, TRUCK_CAPACITY)

        print(f"🚚 Created {len(trucks)} truck trips with enhanced consolidation")

        # Enhanced TSP routing for each truck
        rdc_total_cost = 0
        for truck in trucks:
            # Build locations list
            locations = [(rdc_lon, rdc_lat)]  # RDC at index 0
            for shipto in truck['shiptos']:
                locations.append((shipto['Longitude'], shipto['Latitude']))

            n_locations = len(locations)

            # Pre-compute distance matrix
            dist_matrix = np.zeros((n_locations, n_locations))
            for i in range(n_locations):
                for j in range(i + 1, n_locations):
                    distance = haversine_distance_vectorized(
                        locations[i][1], locations[i][0],  # lat, lon
                        locations[j][1], locations[j][0]
                    )
                    dist_matrix[i][j] = distance
                    dist_matrix[j][i] = distance

            # ENHANCED: Use improved TSP solver
            total_distance, route = enhanced_tsp_solver(locations, dist_matrix)

            # Enhanced cost lookup
            intercept, slope, mode = lookup_cost_enhanced(rdc_state, total_distance, costcurve)
            print(f'Intercept: {intercept}')
            print(f'Slope: {slope}')
            print(f'Mode: {mode}')
            cost = intercept + slope * total_distance

            rdc_total_cost += cost
            all_trucks_details.append({
                'scenario_K': K,
                'rdc_id': rdc_id,
                'rdc_state': rdc_state,
                'truck_id': truck['truck_id'],
                'total_weight': truck['total_weight'],
                'total_distance': total_distance,
                'mode': mode,
                'cost': cost,
                'num_stops': len(truck['shiptos']),
                'capacity_utilization': truck['capacity_utilization']
            })

            print(f"   Truck {truck['truck_id']+1}: {len(truck['shiptos'])} stops, {truck['total_weight']:,.0f} KG")
            print(f"      Route distance: {total_distance:.1f} km, Mode: {mode}, Cost: ${cost:,.0f}")
            print(f"      Capacity utilization: {truck['capacity_utilization']:.1f}%")

        total_branch_delivery_cost += rdc_total_cost
        print(f"💰 RDC {rdc_id} total delivery cost: ${rdc_total_cost:,.0f}")

    print(f"\n🚛 Total Branch Delivery Cost K={K}: ${total_branch_delivery_cost:,.0f}")

    # ========================================================================================
    # STEP 3: HANDLING COSTS WITH CONSISTENT CBM CONVERSION
    # ========================================================================================

    print(f"\n📦 Step 3: Handling Cost Calculation...")

    total_handling_cost = 0
    handling_details = []

    for rdc_id in range(K):
        rdc_shiptos = df_scenario[df_scenario['RDC_Assignment'] == rdc_id]
        if len(rdc_shiptos) == 0:
            continue

        # Use consistent KG to CBM conversion
        total_cbm_handled = rdc_shiptos['Annual_KG_Demand_ShipTo'].sum() / ACTUAL_KG_PER_CBM

        rdc_state = rdc_states[rdc_id]
        location_type = rdc_location_types[rdc_id]

        # Apply location-based cost adjustment
        if location_type == "Urban":
            handling_cost_per_cbm = handling_cost_cbm_curr * URBAN_ADJUSTMENT_FACTOR
        else:
            handling_cost_per_cbm = handling_cost_cbm_curr * RURAL_ADJUSTMENT_FACTOR

        handling_cost_rdc = total_cbm_handled * handling_cost_per_cbm
        total_handling_cost += handling_cost_rdc

        handling_details.append({
            'rdc_id': rdc_id,
            'rdc_state': rdc_state,
            'location_type': location_type,
            'total_cbm': total_cbm_handled,
            'cost_per_cbm': handling_cost_per_cbm,
            'total_cost': handling_cost_rdc
        })

        print(f"📦 RDC {rdc_id} ({rdc_state}, {location_type}): {total_cbm_handled:,.0f} CBM × ${handling_cost_per_cbm:.1f} = ${handling_cost_rdc:,.0f}")

    print(f"\n📦 Total Handling Cost K={K}: ${total_handling_cost:,.0f}")

    # ========================================================================================
    # STEP 4: STORAGE COSTS WITH SQUARE ROOT LAW
    # ========================================================================================

    print(f"\n🏬 Step 4: Storage Cost Calculation with SRL...")
    print(f"📚 SRL Justification: Due to limited data on demand variability (σ_demand),")
    print(f"    supplier lead times, and ordering costs for individual RDCs, we apply the")
    print(f"    Square Root Law as a recognized method for estimating inventory changes.")
    print(f"    Current DC inventory ({avg_inv_cbm_curr:,} CBM) includes both cycle and safety stock.")

    # Apply Square Root Law
    total_inventory_cbm_new = avg_inv_cbm_curr * math.sqrt(K / 1)
    inventory_change_pct = ((total_inventory_cbm_new - avg_inv_cbm_curr) / avg_inv_cbm_curr) * 100

    print(f"📊 SRL Calculation: {avg_inv_cbm_curr:,} × √({K}/1) = {total_inventory_cbm_new:,.0f} CBM")
    print(f"📈 Inventory change: {inventory_change_pct:+.1f}% vs baseline")

    total_storage_cost = 0
    storage_details = []

    # Use consistent CBM for demand-based allocation
    total_system_demand_cbm = df_scenario['Annual_KG_Demand_ShipTo'].sum() / ACTUAL_KG_PER_CBM

    for rdc_id in range(K):
        rdc_shiptos = df_scenario[df_scenario['RDC_Assignment'] == rdc_id]
        if len(rdc_shiptos) == 0:
            continue

        # Allocate inventory based on CBM demand share
        rdc_demand_cbm = rdc_shiptos['Annual_KG_Demand_ShipTo'].sum() / ACTUAL_KG_PER_CBM
        demand_share = rdc_demand_cbm / total_system_demand_cbm
        inventory_at_rdc = total_inventory_cbm_new * demand_share

        # Apply location-based storage cost
        rdc_state = rdc_states[rdc_id]
        location_type = rdc_location_types[rdc_id]

        if location_type == "Urban":
            storage_cost_per_cbm = storage_cost_cbm_curr * URBAN_ADJUSTMENT_FACTOR
        else:
            storage_cost_per_cbm = storage_cost_cbm_curr * RURAL_ADJUSTMENT_FACTOR

        storage_cost_rdc = inventory_at_rdc * storage_cost_per_cbm
        total_storage_cost += storage_cost_rdc

        storage_details.append({
            'rdc_id': rdc_id,
            'rdc_state': rdc_state,
            'location_type': location_type,
            'demand_share': demand_share,
            'inventory_cbm': inventory_at_rdc,
            'cost_per_cbm': storage_cost_per_cbm,
            'total_cost': storage_cost_rdc
        })

        print(f"🏬 RDC {rdc_id} ({rdc_state}, {location_type}): {inventory_at_rdc:,.0f} CBM × ${storage_cost_per_cbm:.1f} = ${storage_cost_rdc:,.0f}")
        print(f"     Demand share: {demand_share*100:.1f}%")

    print(f"\n🏬 Total Storage Cost K={K}: ${total_storage_cost:,.0f}")

    # ========================================================================================
    # STEP 5: CALCULATE TRANSFER COSTS FROM ORIGINAL DC TO RDCs (HUB-AND-SPOKE MODEL)
    # ========================================================================================

    print(f"\n🔄 Step 5: Calculating Transfer Costs from Original DC to RDCs...")
    print(f"📍 Original DC: ({lon_ref}, {lat_ref}) in New South Wales")
    print(f"🚛 Hub-and-Spoke model: Original DC supplies all RDCs")

    total_transfer_cost = 0
    transfer_details = []

    # Get state of original DC for cost curve lookup
    dc_state = "New South Wales"  # Original DC is in NSW

    for rdc_id in range(K):
        rdc_shiptos = df_scenario[df_scenario['RDC_Assignment'] == rdc_id]
        if len(rdc_shiptos) == 0:
            continue

        rdc_lon, rdc_lat = rdc_centers[rdc_id]
        rdc_state = rdc_states[rdc_id]

        # Calculate Haversine distance from Original DC to RDC
        def haversine_distance_transfer(lat1, lon1, lat2, lon2):
            """Calculate Haversine distance between DC and RDC"""
            R = 6371  # Earth radius in km
            lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])
            dlat = lat2 - lat1
            dlon = lon2 - lon1
            a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
            c = 2 * atan2(sqrt(a), sqrt(1 - a))
            return R * c

        transfer_distance = haversine_distance_transfer(lat_ref, lon_ref, rdc_lat, rdc_lon)

        # Calculate annual volume to transfer to this RDC
        annual_kg_to_rdc = rdc_shiptos['Annual_KG_Demand_ShipTo'].sum()

        # Calculate number of truck trips needed
        num_transfer_trips = math.ceil(annual_kg_to_rdc / TRUCK_CAPACITY)

        # Lookup cost curve for transfer from DC (NSW) based on distance
        try:
            intercept, slope, mode = lookup_cost_enhanced(dc_state, transfer_distance, costcurve)
            print(f'Interceptor: {intercept}')
            print(f'Slope: {slope}')
            print(f'Mode: {mode}')
            cost_per_trip = intercept + slope * transfer_distance
        except:
            # Fallback if lookup fails
            if transfer_distance <= 55:
                cost_per_trip = 225.2 + 0.9 * transfer_distance  # FTL NSW
                mode = 'FTL'
            else:
                cost_per_trip = 360.4 + 1.1 * transfer_distance  # LTL NSW
                mode = 'LTL'

        # Calculate total transfer cost for this RDC
        transfer_cost_rdc = num_transfer_trips * cost_per_trip
        total_transfer_cost += transfer_cost_rdc

        # Store transfer details
        transfer_details.append({
            'rdc_id': rdc_id,
            'rdc_state': rdc_state,
            'rdc_coordinates': (rdc_lon, rdc_lat),
            'transfer_distance': transfer_distance,
            'annual_kg': annual_kg_to_rdc,
            'num_trips': num_transfer_trips,
            'cost_per_trip': cost_per_trip,
            'mode': mode,
            'total_cost': transfer_cost_rdc
        })

        print(f"🚛 Transfer to RDC {rdc_id} ({rdc_state}):")
        print(f"    Distance: {transfer_distance:.1f} km")
        print(f"    Annual volume: {annual_kg_to_rdc:,.0f} KG")
        print(f"    Number of trips: {num_transfer_trips}")
        print(f"    Cost per trip: ${cost_per_trip:.2f} ({mode})")
        print(f"    Total transfer cost: ${transfer_cost_rdc:,.0f}")

    print(f"\n🔄 Total Transfer Cost K={K}: ${total_transfer_cost:,.0f}")
    print(f"📊 Transfer Cost Justification:")
    print(f"    • Hub-and-Spoke model: Original DC supplies all RDCs")
    print(f"    • {TRUCK_CAPACITY:,} KG capacity trucks used for transfers")
    print(f"    • Cost curves applied based on DC state (NSW) and transfer distances")
    print(f"    • {sum(detail['num_trips'] for detail in transfer_details)} total transfer trips annually")

    # ========================================================================================
    # STEP 6: CALCULATE TOTAL SCENARIO COST
    # ========================================================================================

    total_cost_scenario = total_branch_delivery_cost + total_handling_cost + total_storage_cost + total_transfer_cost
    savings_vs_baseline = baseline_total_cost - total_cost_scenario
    savings_percentage = (savings_vs_baseline / baseline_total_cost * 100) if baseline_total_cost > 0 else 0

    print(f"\n💰 SCENARIO K={K} TOTAL COST BREAKDOWN:")
    print(f"   🚛 Branch Delivery: ${total_branch_delivery_cost:,.0f} ({total_branch_delivery_cost/total_cost_scenario*100:.1f}%)")
    print(f"   📦 Handling: ${total_handling_cost:,.0f} ({total_handling_cost/total_cost_scenario*100:.1f}%)")
    print(f"   🏬 Storage: ${total_storage_cost:,.0f} ({total_storage_cost/total_cost_scenario*100:.1f}%)")
    print(f"   🔄 Transfer: ${total_transfer_cost:,.0f} ({total_transfer_cost/total_cost_scenario*100:.1f}%)")
    print(f"   🎯 TOTAL: ${total_cost_scenario:,.0f}")
    print(f"   💾 Savings vs Baseline: ${savings_vs_baseline:,.0f} ({savings_percentage:+.1f}%)")

    # Store comprehensive results
    all_scenario_results[K] = {
        'K': K,
        'rdc_centers': rdc_centers,
        'rdc_states': rdc_states,
        'rdc_location_types': rdc_location_types,
        'total_cost': total_cost_scenario,
        'branch_delivery_cost': total_branch_delivery_cost,
        'handling_cost': total_handling_cost,
        'storage_cost': total_storage_cost,
        'transfer_cost': total_transfer_cost,
        'savings_vs_baseline': savings_vs_baseline,
        'savings_percentage': savings_percentage,
        'trucks_details': all_trucks_details,
        'handling_details': handling_details,
        'storage_details': storage_details,
        'transfer_details': transfer_details,
        'scenario_data': df_scenario,
        'total_inventory_cbm': total_inventory_cbm_new
    }
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
#       Capacity utilization: 99.7%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 77: 10 stops, 19,989 KG
#       Route distance: 4056.5 km, Mode: LTL, Cost: $4,823
#       Capacity utilization: 99.9%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 78: 10 stops, 19,837 KG
#       Route distance: 3171.1 km, Mode: LTL, Cost: $3,849
#       Capacity utilization: 99.2%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 79: 11 stops, 19,996 KG
#       Route distance: 5192.7 km, Mode: LTL, Cost: $6,072
#       Capacity utilization: 100.0%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 80: 11 stops, 19,751 KG
#       Route distance: 3253.7 km, Mode: LTL, Cost: $3,939
#       Capacity utilization: 98.8%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 81: 12 stops, 19,979 KG
#       Route distance: 4255.6 km, Mode: LTL, Cost: $5,042
#       Capacity utilization: 99.9%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 82: 12 stops, 19,297 KG
#       Route distance: 3360.9 km, Mode: LTL, Cost: $4,057
#       Capacity utilization: 96.5%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 83: 13 stops, 19,792 KG
#       Route distance: 5222.3 km, Mode: LTL, Cost: $6,105
#       Capacity utilization: 99.0%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 84: 14 stops, 19,888 KG
#       Route distance: 5126.9 km, Mode: LTL, Cost: $6,000
#       Capacity utilization: 99.4%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 85: 17 stops, 19,739 KG
#       Route distance: 4603.2 km, Mode: LTL, Cost: $5,424
#       Capacity utilization: 98.7%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 86: 17 stops, 16,120 KG
#       Route distance: 5125.3 km, Mode: LTL, Cost: $5,998
#       Capacity utilization: 80.6%
# 💰 RDC 0 total delivery cost: $259,577
#
# --- RDC 1 Analysis (Western Australia) ---
# 🏢 RDC 1: (118.482, -28.627) in Western Australia
# 📦 Serves 51 ShipToIDs
# ⚖️ Total demand: 287,466 KG
# 🚚 Created 15 truck trips with enhanced consolidation
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 1: 3 stops, 19,712 KG
#       Route distance: 617.3 km, Mode: LTL, Cost: $551
#       Capacity utilization: 98.6%
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 2: 2 stops, 19,932 KG
#       Route distance: 444.5 km, Mode: LTL, Cost: $464
#       Capacity utilization: 99.7%
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 3: 2 stops, 19,768 KG
#       Route distance: 473.3 km, Mode: LTL, Cost: $479
#       Capacity utilization: 98.8%
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 4: 2 stops, 19,834 KG
#       Route distance: 455.8 km, Mode: LTL, Cost: $470
#       Capacity utilization: 99.2%
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 5: 3 stops, 19,907 KG
#       Route distance: 3468.6 km, Mode: LTL, Cost: $1,976
#       Capacity utilization: 99.5%
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 6: 3 stops, 19,911 KG
#       Route distance: 606.2 km, Mode: LTL, Cost: $545
#       Capacity utilization: 99.6%
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 7: 3 stops, 19,688 KG
#       Route distance: 761.5 km, Mode: LTL, Cost: $623
#       Capacity utilization: 98.4%
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 8: 3 stops, 19,951 KG
#       Route distance: 919.0 km, Mode: LTL, Cost: $702
#       Capacity utilization: 99.8%
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 9: 4 stops, 19,930 KG
#       Route distance: 614.7 km, Mode: LTL, Cost: $550
#       Capacity utilization: 99.6%
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 10: 4 stops, 19,779 KG
#       Route distance: 3319.3 km, Mode: LTL, Cost: $1,902
#       Capacity utilization: 98.9%
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 11: 4 stops, 19,871 KG
#       Route distance: 495.1 km, Mode: LTL, Cost: $490
#       Capacity utilization: 99.4%
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 12: 4 stops, 19,377 KG
#       Route distance: 1702.6 km, Mode: LTL, Cost: $1,094
#       Capacity utilization: 96.9%
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 13: 4 stops, 19,529 KG
#       Route distance: 993.9 km, Mode: LTL, Cost: $739
#       Capacity utilization: 97.6%
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 14: 5 stops, 19,127 KG
#       Route distance: 3565.8 km, Mode: LTL, Cost: $2,025
#       Capacity utilization: 95.6%
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 15: 5 stops, 11,149 KG
#       Route distance: 2951.4 km, Mode: LTL, Cost: $1,718
#       Capacity utilization: 55.7%
# 💰 RDC 1 total delivery cost: $14,328
#
# 🚛 Total Branch Delivery Cost K=2: $273,905
#
# 📦 Step 3: Handling Cost Calculation...
# 📦 RDC 0 (New South Wales, Rural): 12,947 CBM × $7.0 = $90,632
# 📦 RDC 1 (Western Australia, Rural): 2,001 CBM × $7.0 = $14,008
#
# 📦 Total Handling Cost K=2: $104,640
#
# 🏬 Step 4: Storage Cost Calculation with SRL...
# 📚 SRL Justification: Due to limited data on demand variability (σ_demand),
#     supplier lead times, and ordering costs for individual RDCs, we apply the
#     Square Root Law as a recognized method for estimating inventory changes.
#     Current DC inventory (14,898 CBM) includes both cycle and safety stock.
# 📊 SRL Calculation: 14,898 × √(2/1) = 21,069 CBM
# 📈 Inventory change: +41.4% vs baseline
# 🏬 RDC 0 (New South Wales, Rural): 18,248 CBM × $21.0 = $383,218
#      Demand share: 86.6%
# 🏬 RDC 1 (Western Australia, Rural): 2,820 CBM × $21.0 = $59,230
#      Demand share: 13.4%
#
# 🏬 Total Storage Cost K=2: $442,448
#
# 🔄 Step 5: Calculating Transfer Costs from Original DC to RDCs...
# 📍 Original DC: (151.1250996, -29.79165152) in New South Wales
# 🚛 Hub-and-Spoke model: Original DC supplies all RDCs
# Interceptor: 360.4
# Slope: 1.1
# Mode: LTL
# 🚛 Transfer to RDC 0 (New South Wales):
#     Distance: 489.7 km
#     Annual volume: 1,859,902 KG
#     Number of trips: 93
#     Cost per trip: $899.04 (LTL)
#     Total transfer cost: $83,611
# Interceptor: 360.4
# Slope: 1.1
# Mode: LTL
# 🚛 Transfer to RDC 1 (Western Australia):
#     Distance: 3160.3 km
#     Annual volume: 287,466 KG
#     Number of trips: 15
#     Cost per trip: $3836.68 (LTL)
#     Total transfer cost: $57,550
#
# 🔄 Total Transfer Cost K=2: $141,161
# 📊 Transfer Cost Justification:
#     • Hub-and-Spoke model: Original DC supplies all RDCs
#     • 20,000 KG capacity trucks used for transfers
#     • Cost curves applied based on DC state (NSW) and transfer distances
#     • 108 total transfer trips annually
#
# 💰 SCENARIO K=2 TOTAL COST BREAKDOWN:
#    🚛 Branch Delivery: $273,905 (28.5%)
#    📦 Handling: $104,640 (10.9%)
#    🏬 Storage: $442,448 (46.0%)
#    🔄 Transfer: $141,161 (14.7%)
#    🎯 TOTAL: $962,155
#    💾 Savings vs Baseline: $2,116,272 (+68.7%)
#
# ============================================================
# 🎯 EVALUATING SCENARIO K = 3 RDCs
# ============================================================
# 📍 Step 1: K-Means clustering with standardized data for K=3...
# ✅ K-Means completed. Determining RDC characteristics...
# ✅ Geopy: New South Wales for (-35.849, 146.764)
#    RDC 0: (146.764, -35.849) - New South Wales (Rural)
#            Serves 325 ShipToIDs, 1,451,480 KG
# ✅ Geopy: Queensland for (-24.917, 150.190)
#    RDC 1: (150.190, -24.917) - Queensland (Rural)
#            Serves 118 ShipToIDs, 433,230 KG
# ✅ Geopy: Western Australia for (-31.329, 116.069)
#    RDC 2: (116.069, -31.329) - Western Australia (Rural)
#            Serves 43 ShipToIDs, 262,657 KG
#
# 🚛 Step 2: Branch Delivery Cost Calculation...
#
# --- RDC 0 Analysis (New South Wales) ---
# 🏢 RDC 0: (146.764, -35.849) in New South Wales
# 📦 Serves 325 ShipToIDs
# ⚖️ Total demand: 1,451,480 KG
# ⚠️ Removing problematic shipment: 4795BR
# ⚠️ Removing problematic shipment: 4880BR
# ⚠️ Removing problematic shipment: 3211BR
# ⚠️ Removing problematic shipment: 4217BR
# ⚠️ Removing problematic shipment: 3172BR
# ⚠️ Removing problematic shipment: 4048BR
# 🚚 Created 66 truck trips with enhanced consolidation
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 1: 1 stops, 20,000 KG
#       Route distance: 534.0 km, Mode: LTL, Cost: $948
#       Capacity utilization: 100.0%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 2: 1 stops, 20,000 KG
#       Route distance: 555.2 km, Mode: LTL, Cost: $971
#       Capacity utilization: 100.0%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 3: 1 stops, 20,000 KG
#       Route distance: 877.7 km, Mode: LTL, Cost: $1,326
#       Capacity utilization: 100.0%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 4: 1 stops, 20,000 KG
#       Route distance: 652.0 km, Mode: LTL, Cost: $1,078
#       Capacity utilization: 100.0%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 5: 1 stops, 20,000 KG
#       Route distance: 915.5 km, Mode: LTL, Cost: $1,367
#       Capacity utilization: 100.0%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 6: 1 stops, 20,000 KG
#       Route distance: 515.4 km, Mode: LTL, Cost: $927
#       Capacity utilization: 100.0%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 7: 3 stops, 19,964 KG
#       Route distance: 1098.7 km, Mode: LTL, Cost: $1,569
#       Capacity utilization: 99.8%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 8: 1 stops, 19,824 KG
#       Route distance: 1495.5 km, Mode: LTL, Cost: $2,005
#       Capacity utilization: 99.1%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 9: 2 stops, 19,976 KG
#       Route distance: 973.8 km, Mode: LTL, Cost: $1,432
#       Capacity utilization: 99.9%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 10: 2 stops, 19,995 KG
#       Route distance: 287.2 km, Mode: LTL, Cost: $676
#       Capacity utilization: 100.0%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 11: 2 stops, 19,968 KG
#       Route distance: 651.1 km, Mode: LTL, Cost: $1,077
#       Capacity utilization: 99.8%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 12: 2 stops, 19,921 KG
#       Route distance: 777.0 km, Mode: LTL, Cost: $1,215
#       Capacity utilization: 99.6%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 13: 2 stops, 19,975 KG
#       Route distance: 900.3 km, Mode: LTL, Cost: $1,351
#       Capacity utilization: 99.9%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 14: 2 stops, 19,915 KG
#       Route distance: 297.9 km, Mode: LTL, Cost: $688
#       Capacity utilization: 99.6%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 15: 2 stops, 19,996 KG
#       Route distance: 400.8 km, Mode: LTL, Cost: $801
#       Capacity utilization: 100.0%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 16: 2 stops, 19,982 KG
#       Route distance: 284.3 km, Mode: LTL, Cost: $673
#       Capacity utilization: 99.9%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 17: 3 stops, 19,981 KG
#       Route distance: 949.4 km, Mode: LTL, Cost: $1,405
#       Capacity utilization: 99.9%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 18: 3 stops, 19,900 KG
#       Route distance: 1009.9 km, Mode: LTL, Cost: $1,471
#       Capacity utilization: 99.5%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 19: 2 stops, 19,923 KG
#       Route distance: 1412.1 km, Mode: LTL, Cost: $1,914
#       Capacity utilization: 99.6%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 20: 2 stops, 19,965 KG
#       Route distance: 995.0 km, Mode: LTL, Cost: $1,455
#       Capacity utilization: 99.8%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 21: 2 stops, 19,988 KG
#       Route distance: 846.1 km, Mode: LTL, Cost: $1,291
#       Capacity utilization: 99.9%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 22: 2 stops, 19,727 KG
#       Route distance: 1222.3 km, Mode: LTL, Cost: $1,705
#       Capacity utilization: 98.6%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 23: 2 stops, 19,460 KG
#       Route distance: 733.5 km, Mode: LTL, Cost: $1,167
#       Capacity utilization: 97.3%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 24: 2 stops, 19,799 KG
#       Route distance: 965.2 km, Mode: LTL, Cost: $1,422
#       Capacity utilization: 99.0%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 25: 2 stops, 19,578 KG
#       Route distance: 446.7 km, Mode: LTL, Cost: $852
#       Capacity utilization: 97.9%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 26: 3 stops, 19,989 KG
#       Route distance: 1225.2 km, Mode: LTL, Cost: $1,708
#       Capacity utilization: 99.9%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 27: 3 stops, 19,998 KG
#       Route distance: 1710.7 km, Mode: LTL, Cost: $2,242
#       Capacity utilization: 100.0%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 28: 3 stops, 19,955 KG
#       Route distance: 1114.4 km, Mode: LTL, Cost: $1,586
#       Capacity utilization: 99.8%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 29: 3 stops, 19,847 KG
#       Route distance: 1269.9 km, Mode: LTL, Cost: $1,757
#       Capacity utilization: 99.2%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 30: 3 stops, 19,958 KG
#       Route distance: 703.5 km, Mode: LTL, Cost: $1,134
#       Capacity utilization: 99.8%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 31: 3 stops, 19,883 KG
#       Route distance: 1240.5 km, Mode: LTL, Cost: $1,725
#       Capacity utilization: 99.4%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 32: 3 stops, 19,968 KG
#       Route distance: 974.4 km, Mode: LTL, Cost: $1,432
#       Capacity utilization: 99.8%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 33: 3 stops, 19,731 KG
#       Route distance: 1587.2 km, Mode: LTL, Cost: $2,106
#       Capacity utilization: 98.7%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 34: 4 stops, 19,984 KG
#       Route distance: 1046.0 km, Mode: LTL, Cost: $1,511
#       Capacity utilization: 99.9%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 35: 4 stops, 19,997 KG
#       Route distance: 2270.8 km, Mode: LTL, Cost: $2,858
#       Capacity utilization: 100.0%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 36: 4 stops, 19,995 KG
#       Route distance: 949.8 km, Mode: LTL, Cost: $1,405
#       Capacity utilization: 100.0%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 37: 4 stops, 20,000 KG
#       Route distance: 1013.2 km, Mode: LTL, Cost: $1,475
#       Capacity utilization: 100.0%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 38: 4 stops, 19,985 KG
#       Route distance: 2136.5 km, Mode: LTL, Cost: $2,711
#       Capacity utilization: 99.9%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 39: 4 stops, 19,987 KG
#       Route distance: 1049.8 km, Mode: LTL, Cost: $1,515
#       Capacity utilization: 99.9%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 40: 5 stops, 19,977 KG
#       Route distance: 1205.3 km, Mode: LTL, Cost: $1,686
#       Capacity utilization: 99.9%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 41: 5 stops, 19,983 KG
#       Route distance: 2705.2 km, Mode: LTL, Cost: $3,336
#       Capacity utilization: 99.9%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 42: 5 stops, 19,995 KG
#       Route distance: 1133.8 km, Mode: LTL, Cost: $1,608
#       Capacity utilization: 100.0%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 43: 5 stops, 19,860 KG
#       Route distance: 1066.4 km, Mode: LTL, Cost: $1,533
#       Capacity utilization: 99.3%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 44: 6 stops, 19,931 KG
#       Route distance: 2405.7 km, Mode: LTL, Cost: $3,007
#       Capacity utilization: 99.7%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 45: 6 stops, 19,990 KG
#       Route distance: 2054.2 km, Mode: LTL, Cost: $2,620
#       Capacity utilization: 100.0%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 46: 6 stops, 19,998 KG
#       Route distance: 1928.9 km, Mode: LTL, Cost: $2,482
#       Capacity utilization: 100.0%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 47: 7 stops, 19,990 KG
#       Route distance: 2132.5 km, Mode: LTL, Cost: $2,706
#       Capacity utilization: 99.9%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 48: 7 stops, 19,996 KG
#       Route distance: 2146.3 km, Mode: LTL, Cost: $2,721
#       Capacity utilization: 100.0%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 49: 7 stops, 19,966 KG
#       Route distance: 1390.2 km, Mode: LTL, Cost: $1,890
#       Capacity utilization: 99.8%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 50: 7 stops, 19,962 KG
#       Route distance: 3109.1 km, Mode: LTL, Cost: $3,780
#       Capacity utilization: 99.8%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 51: 7 stops, 19,769 KG
#       Route distance: 1198.3 km, Mode: LTL, Cost: $1,679
#       Capacity utilization: 98.8%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 52: 8 stops, 19,991 KG
#       Route distance: 1121.9 km, Mode: LTL, Cost: $1,595
#       Capacity utilization: 100.0%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 53: 8 stops, 19,995 KG
#       Route distance: 2521.5 km, Mode: LTL, Cost: $3,134
#       Capacity utilization: 100.0%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 54: 8 stops, 19,987 KG
#       Route distance: 2438.0 km, Mode: LTL, Cost: $3,042
#       Capacity utilization: 99.9%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 55: 9 stops, 19,977 KG
#       Route distance: 2434.3 km, Mode: LTL, Cost: $3,038
#       Capacity utilization: 99.9%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 56: 9 stops, 19,981 KG
#       Route distance: 2460.8 km, Mode: LTL, Cost: $3,067
#       Capacity utilization: 99.9%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 57: 9 stops, 19,926 KG
#       Route distance: 2183.1 km, Mode: LTL, Cost: $2,762
#       Capacity utilization: 99.6%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 58: 10 stops, 19,936 KG
#       Route distance: 1808.2 km, Mode: LTL, Cost: $2,349
#       Capacity utilization: 99.7%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 59: 10 stops, 19,994 KG
#       Route distance: 3266.0 km, Mode: LTL, Cost: $3,953
#       Capacity utilization: 100.0%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 60: 11 stops, 19,842 KG
#       Route distance: 2863.3 km, Mode: LTL, Cost: $3,510
#       Capacity utilization: 99.2%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 61: 11 stops, 19,711 KG
#       Route distance: 2911.8 km, Mode: LTL, Cost: $3,563
#       Capacity utilization: 98.6%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 62: 12 stops, 19,780 KG
#       Route distance: 2758.5 km, Mode: LTL, Cost: $3,395
#       Capacity utilization: 98.9%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 63: 13 stops, 19,743 KG
#       Route distance: 1474.8 km, Mode: LTL, Cost: $1,983
#       Capacity utilization: 98.7%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 64: 15 stops, 19,842 KG
#       Route distance: 2981.7 km, Mode: LTL, Cost: $3,640
#       Capacity utilization: 99.2%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 65: 19 stops, 19,976 KG
#       Route distance: 3141.7 km, Mode: LTL, Cost: $3,816
#       Capacity utilization: 99.9%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 66: 6 stops, 5,173 KG
#       Route distance: 2258.9 km, Mode: LTL, Cost: $2,845
#       Capacity utilization: 25.9%
# 💰 RDC 0 total delivery cost: $130,695
#
# --- RDC 1 Analysis (Queensland) ---
# 🏢 RDC 1: (150.190, -24.917) in Queensland
# 📦 Serves 118 ShipToIDs
# ⚖️ Total demand: 433,230 KG
# 🚚 Created 22 truck trips with enhanced consolidation
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 1: 3 stops, 19,847 KG
#       Route distance: 1649.6 km, Mode: LTL, Cost: $722
#       Capacity utilization: 99.2%
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 2: 2 stops, 19,750 KG
#       Route distance: 1795.3 km, Mode: LTL, Cost: $765
#       Capacity utilization: 98.8%
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 3: 2 stops, 19,315 KG
#       Route distance: 525.7 km, Mode: LTL, Cost: $384
#       Capacity utilization: 96.6%
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 4: 2 stops, 19,981 KG
#       Route distance: 3260.0 km, Mode: LTL, Cost: $1,205
#       Capacity utilization: 99.9%
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 5: 3 stops, 19,960 KG
#       Route distance: 3271.8 km, Mode: LTL, Cost: $1,208
#       Capacity utilization: 99.8%
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 6: 3 stops, 19,879 KG
#       Route distance: 545.7 km, Mode: LTL, Cost: $390
#       Capacity utilization: 99.4%
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 7: 3 stops, 19,998 KG
#       Route distance: 468.8 km, Mode: LTL, Cost: $367
#       Capacity utilization: 100.0%
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 8: 3 stops, 19,921 KG
#       Route distance: 722.8 km, Mode: LTL, Cost: $444
#       Capacity utilization: 99.6%
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 9: 3 stops, 19,603 KG
#       Route distance: 581.1 km, Mode: LTL, Cost: $401
#       Capacity utilization: 98.0%
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 10: 4 stops, 19,986 KG
#       Route distance: 786.8 km, Mode: LTL, Cost: $463
#       Capacity utilization: 99.9%
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 11: 4 stops, 19,680 KG
#       Route distance: 512.4 km, Mode: LTL, Cost: $380
#       Capacity utilization: 98.4%
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 12: 4 stops, 19,630 KG
#       Route distance: 1583.7 km, Mode: LTL, Cost: $702
#       Capacity utilization: 98.2%
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 13: 5 stops, 19,968 KG
#       Route distance: 498.2 km, Mode: LTL, Cost: $376
#       Capacity utilization: 99.8%
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 14: 6 stops, 19,996 KG
#       Route distance: 2420.1 km, Mode: LTL, Cost: $953
#       Capacity utilization: 100.0%
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 15: 6 stops, 19,999 KG
#       Route distance: 2885.4 km, Mode: LTL, Cost: $1,092
#       Capacity utilization: 100.0%
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 16: 7 stops, 19,910 KG
#       Route distance: 3592.7 km, Mode: LTL, Cost: $1,305
#       Capacity utilization: 99.6%
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 17: 7 stops, 19,788 KG
#       Route distance: 1841.8 km, Mode: LTL, Cost: $779
#       Capacity utilization: 98.9%
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 18: 8 stops, 19,992 KG
#       Route distance: 4036.1 km, Mode: LTL, Cost: $1,438
#       Capacity utilization: 100.0%
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 19: 9 stops, 19,986 KG
#       Route distance: 1037.4 km, Mode: LTL, Cost: $538
#       Capacity utilization: 99.9%
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 20: 10 stops, 19,927 KG
#       Route distance: 3561.3 km, Mode: LTL, Cost: $1,295
#       Capacity utilization: 99.6%
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 21: 11 stops, 19,137 KG
#       Route distance: 4566.5 km, Mode: LTL, Cost: $1,597
#       Capacity utilization: 95.7%
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 22: 13 stops, 16,977 KG
#       Route distance: 4120.5 km, Mode: LTL, Cost: $1,463
#       Capacity utilization: 84.9%
# 💰 RDC 1 total delivery cost: $18,267
#
# --- RDC 2 Analysis (Western Australia) ---
# 🏢 RDC 2: (116.069, -31.329) in Western Australia
# 📦 Serves 43 ShipToIDs
# ⚖️ Total demand: 262,657 KG
# 🚚 Created 14 truck trips with enhanced consolidation
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 1: 3 stops, 19,712 KG
#       Route distance: 240.1 km, Mode: LTL, Cost: $362
#       Capacity utilization: 98.6%
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 2: 2 stops, 19,932 KG
#       Route distance: 74.5 km, Mode: LTL, Cost: $279
#       Capacity utilization: 99.7%
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 3: 2 stops, 19,768 KG
#       Route distance: 93.5 km, Mode: LTL, Cost: $289
#       Capacity utilization: 98.8%
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 4: 2 stops, 19,834 KG
#       Route distance: 80.3 km, Mode: LTL, Cost: $282
#       Capacity utilization: 99.2%
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 5: 4 stops, 19,244 KG
#       Route distance: 1633.7 km, Mode: LTL, Cost: $1,059
#       Capacity utilization: 96.2%
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 6: 3 stops, 19,592 KG
#       Route distance: 93.9 km, Mode: LTL, Cost: $289
#       Capacity utilization: 98.0%
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 7: 3 stops, 19,925 KG
#       Route distance: 1194.9 km, Mode: LTL, Cost: $840
#       Capacity utilization: 99.6%
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 8: 3 stops, 19,969 KG
#       Route distance: 231.2 km, Mode: LTL, Cost: $358
#       Capacity utilization: 99.8%
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 9: 3 stops, 19,637 KG
#       Route distance: 1380.9 km, Mode: LTL, Cost: $933
#       Capacity utilization: 98.2%
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 10: 3 stops, 17,253 KG
#       Route distance: 114.0 km, Mode: LTL, Cost: $299
#       Capacity utilization: 86.3%
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 11: 4 stops, 19,568 KG
#       Route distance: 95.1 km, Mode: LTL, Cost: $290
#       Capacity utilization: 97.8%
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 12: 4 stops, 19,653 KG
#       Route distance: 1715.0 km, Mode: LTL, Cost: $1,100
#       Capacity utilization: 98.3%
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 13: 4 stops, 19,228 KG
#       Route distance: 714.1 km, Mode: LTL, Cost: $599
#       Capacity utilization: 96.1%
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 14: 3 stops, 9,342 KG
#       Route distance: 307.7 km, Mode: LTL, Cost: $396
#       Capacity utilization: 46.7%
# 💰 RDC 2 total delivery cost: $7,375
#
# 🚛 Total Branch Delivery Cost K=3: $156,337
#
# 📦 Step 3: Handling Cost Calculation...
# 📦 RDC 0 (New South Wales, Rural): 10,104 CBM × $7.0 = $70,730
# 📦 RDC 1 (Queensland, Rural): 3,016 CBM × $7.0 = $21,111
# 📦 RDC 2 (Western Australia, Rural): 1,828 CBM × $7.0 = $12,799
#
# 📦 Total Handling Cost K=3: $104,640
#
# 🏬 Step 4: Storage Cost Calculation with SRL...
# 📚 SRL Justification: Due to limited data on demand variability (σ_demand),
#     supplier lead times, and ordering costs for individual RDCs, we apply the
#     Square Root Law as a recognized method for estimating inventory changes.
#     Current DC inventory (14,898 CBM) includes both cycle and safety stock.
# 📊 SRL Calculation: 14,898 × √(3/1) = 25,804 CBM
# 📈 Inventory change: +73.2% vs baseline
# 🏬 RDC 0 (New South Wales, Rural): 17,442 CBM × $21.0 = $366,279
#      Demand share: 67.6%
# 🏬 RDC 1 (Queensland, Rural): 5,206 CBM × $21.0 = $109,325
#      Demand share: 20.2%
# 🏬 RDC 2 (Western Australia, Rural): 3,156 CBM × $21.0 = $66,281
#      Demand share: 12.2%
#
# 🏬 Total Storage Cost K=3: $541,886
#
# 🔄 Step 5: Calculating Transfer Costs from Original DC to RDCs...
# 📍 Original DC: (151.1250996, -29.79165152) in New South Wales
# 🚛 Hub-and-Spoke model: Original DC supplies all RDCs
# Interceptor: 360.4
# Slope: 1.1
# Mode: LTL
# 🚛 Transfer to RDC 0 (New South Wales):
#     Distance: 787.0 km
#     Annual volume: 1,451,480 KG
#     Number of trips: 73
#     Cost per trip: $1226.06 (LTL)
#     Total transfer cost: $89,502
# Interceptor: 360.4
# Slope: 1.1
# Mode: LTL
# 🚛 Transfer to RDC 1 (Queensland):
#     Distance: 549.9 km
#     Annual volume: 433,230 KG
#     Number of trips: 22
#     Cost per trip: $965.28 (LTL)
#     Total transfer cost: $21,236
# Interceptor: 360.4
# Slope: 1.1
# Mode: LTL
# 🚛 Transfer to RDC 2 (Western Australia):
#     Distance: 3346.8 km
#     Annual volume: 262,657 KG
#     Number of trips: 14
#     Cost per trip: $4041.92 (LTL)
#     Total transfer cost: $56,587
#
# 🔄 Total Transfer Cost K=3: $167,325
# 📊 Transfer Cost Justification:
#     • Hub-and-Spoke model: Original DC supplies all RDCs
#     • 20,000 KG capacity trucks used for transfers
#     • Cost curves applied based on DC state (NSW) and transfer distances
#     • 109 total transfer trips annually
#
# 💰 SCENARIO K=3 TOTAL COST BREAKDOWN:
#    🚛 Branch Delivery: $156,337 (16.1%)
#    📦 Handling: $104,640 (10.8%)
#    🏬 Storage: $541,886 (55.9%)
#    🔄 Transfer: $167,325 (17.2%)
#    🎯 TOTAL: $970,188
#    💾 Savings vs Baseline: $2,108,239 (+68.5%)
#
# ============================================================
# 🎯 EVALUATING SCENARIO K = 4 RDCs
# ============================================================
# 📍 Step 1: K-Means clustering with standardized data for K=4...
# ✅ K-Means completed. Determining RDC characteristics...
# ✅ Geopy: Victoria for (-37.217, 144.264)
#    RDC 0: (144.264, -37.217) - Victoria (Rural)
#            Serves 205 ShipToIDs, 1,016,552 KG
# ✅ Geopy: Western Australia for (-31.329, 116.069)
#    RDC 1: (116.069, -31.329) - Western Australia (Rural)
#            Serves 43 ShipToIDs, 262,657 KG
# ✅ Geopy: New South Wales for (-31.081, 151.795)
#    RDC 2: (151.795, -31.081) - New South Wales (Rural)
#            Serves 203 ShipToIDs, 767,647 KG
# ✅ Geopy: Queensland for (-18.629, 143.780)
#    RDC 3: (143.780, -18.629) - Queensland (Rural)
#            Serves 35 ShipToIDs, 100,511 KG
#
# 🚛 Step 2: Branch Delivery Cost Calculation...
#
# --- RDC 0 Analysis (Victoria) ---
# 🏢 RDC 0: (144.264, -37.217) in Victoria
# 📦 Serves 205 ShipToIDs
# ⚖️ Total demand: 1,016,552 KG
# ⚠️ Removing problematic shipment: 4795BR
# ⚠️ Removing problematic shipment: 4880BR
# ⚠️ Removing problematic shipment: 4217BR
# ⚠️ Removing problematic shipment: 4048BR
# 🚚 Created 45 truck trips with enhanced consolidation
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 1: 1 stops, 20,000 KG
#       Route distance: 147.5 km, Mode: LTL, Cost: $364
#       Capacity utilization: 100.0%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 2: 1 stops, 20,000 KG
#       Route distance: 248.6 km, Mode: LTL, Cost: $385
#       Capacity utilization: 100.0%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 3: 1 stops, 20,000 KG
#       Route distance: 113.3 km, Mode: LTL, Cost: $357
#       Capacity utilization: 100.0%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 4: 1 stops, 20,000 KG
#       Route distance: 156.1 km, Mode: LTL, Cost: $366
#       Capacity utilization: 100.0%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 5: 2 stops, 19,962 KG
#       Route distance: 460.8 km, Mode: LTL, Cost: $427
#       Capacity utilization: 99.8%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 6: 1 stops, 19,824 KG
#       Route distance: 1139.7 km, Mode: LTL, Cost: $563
#       Capacity utilization: 99.1%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 7: 2 stops, 19,976 KG
#       Route distance: 769.6 km, Mode: LTL, Cost: $489
#       Capacity utilization: 99.9%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 8: 2 stops, 19,995 KG
#       Route distance: 136.8 km, Mode: LTL, Cost: $362
#       Capacity utilization: 100.0%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 9: 2 stops, 19,968 KG
#       Route distance: 507.2 km, Mode: LTL, Cost: $436
#       Capacity utilization: 99.8%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 10: 2 stops, 19,921 KG
#       Route distance: 780.2 km, Mode: LTL, Cost: $491
#       Capacity utilization: 99.6%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 11: 2 stops, 19,915 KG
#       Route distance: 350.9 km, Mode: LTL, Cost: $405
#       Capacity utilization: 99.6%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 12: 2 stops, 19,996 KG
#       Route distance: 230.4 km, Mode: LTL, Cost: $381
#       Capacity utilization: 100.0%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 13: 2 stops, 19,982 KG
#       Route distance: 124.7 km, Mode: LTL, Cost: $360
#       Capacity utilization: 99.9%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 14: 3 stops, 19,981 KG
#       Route distance: 784.2 km, Mode: LTL, Cost: $492
#       Capacity utilization: 99.9%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 15: 2 stops, 19,703 KG
#       Route distance: 81.3 km, Mode: LTL, Cost: $351
#       Capacity utilization: 98.5%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 16: 2 stops, 19,910 KG
#       Route distance: 589.4 km, Mode: LTL, Cost: $453
#       Capacity utilization: 99.5%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 17: 2 stops, 19,948 KG
#       Route distance: 505.3 km, Mode: LTL, Cost: $436
#       Capacity utilization: 99.7%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 18: 2 stops, 19,988 KG
#       Route distance: 691.0 km, Mode: LTL, Cost: $473
#       Capacity utilization: 99.9%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 19: 2 stops, 19,386 KG
#       Route distance: 165.4 km, Mode: LTL, Cost: $368
#       Capacity utilization: 96.9%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 20: 3 stops, 19,955 KG
#       Route distance: 572.4 km, Mode: LTL, Cost: $449
#       Capacity utilization: 99.8%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 21: 2 stops, 19,675 KG
#       Route distance: 583.6 km, Mode: LTL, Cost: $452
#       Capacity utilization: 98.4%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 22: 3 stops, 19,994 KG
#       Route distance: 1464.8 km, Mode: LTL, Cost: $628
#       Capacity utilization: 100.0%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 23: 3 stops, 19,991 KG
#       Route distance: 121.9 km, Mode: LTL, Cost: $359
#       Capacity utilization: 100.0%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 24: 3 stops, 19,770 KG
#       Route distance: 1513.7 km, Mode: LTL, Cost: $638
#       Capacity utilization: 98.9%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 25: 4 stops, 19,945 KG
#       Route distance: 516.0 km, Mode: LTL, Cost: $438
#       Capacity utilization: 99.7%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 26: 4 stops, 19,977 KG
#       Route distance: 1286.2 km, Mode: LTL, Cost: $592
#       Capacity utilization: 99.9%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 27: 4 stops, 19,970 KG
#       Route distance: 375.9 km, Mode: LTL, Cost: $410
#       Capacity utilization: 99.9%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 28: 4 stops, 19,867 KG
#       Route distance: 326.6 km, Mode: LTL, Cost: $400
#       Capacity utilization: 99.3%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 29: 5 stops, 19,998 KG
#       Route distance: 761.7 km, Mode: LTL, Cost: $487
#       Capacity utilization: 100.0%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 30: 5 stops, 19,989 KG
#       Route distance: 1934.6 km, Mode: LTL, Cost: $722
#       Capacity utilization: 99.9%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 31: 5 stops, 19,994 KG
#       Route distance: 435.2 km, Mode: LTL, Cost: $422
#       Capacity utilization: 100.0%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 32: 5 stops, 19,387 KG
#       Route distance: 171.9 km, Mode: LTL, Cost: $369
#       Capacity utilization: 96.9%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 33: 6 stops, 19,980 KG
#       Route distance: 2619.4 km, Mode: LTL, Cost: $859
#       Capacity utilization: 99.9%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 34: 7 stops, 19,972 KG
#       Route distance: 1810.1 km, Mode: LTL, Cost: $697
#       Capacity utilization: 99.9%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 35: 7 stops, 19,998 KG
#       Route distance: 1306.6 km, Mode: LTL, Cost: $596
#       Capacity utilization: 100.0%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 36: 7 stops, 19,971 KG
#       Route distance: 2213.8 km, Mode: LTL, Cost: $778
#       Capacity utilization: 99.9%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 37: 7 stops, 19,672 KG
#       Route distance: 873.5 km, Mode: LTL, Cost: $510
#       Capacity utilization: 98.4%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 38: 8 stops, 19,945 KG
#       Route distance: 1445.4 km, Mode: LTL, Cost: $624
#       Capacity utilization: 99.7%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 39: 8 stops, 19,952 KG
#       Route distance: 2612.4 km, Mode: LTL, Cost: $857
#       Capacity utilization: 99.8%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 40: 9 stops, 19,986 KG
#       Route distance: 2026.0 km, Mode: LTL, Cost: $740
#       Capacity utilization: 99.9%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 41: 10 stops, 19,983 KG
#       Route distance: 3187.9 km, Mode: LTL, Cost: $972
#       Capacity utilization: 99.9%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 42: 12 stops, 19,978 KG
#       Route distance: 1365.4 km, Mode: LTL, Cost: $608
#       Capacity utilization: 99.9%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 43: 13 stops, 19,752 KG
#       Route distance: 2174.5 km, Mode: LTL, Cost: $770
#       Capacity utilization: 98.8%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 44: 16 stops, 19,474 KG
#       Route distance: 2778.6 km, Mode: LTL, Cost: $891
#       Capacity utilization: 97.4%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 45: 11 stops, 10,165 KG
#       Route distance: 2004.3 km, Mode: LTL, Cost: $736
#       Capacity utilization: 50.8%
# 💰 RDC 0 total delivery cost: $23,959
#
# --- RDC 1 Analysis (Western Australia) ---
# 🏢 RDC 1: (116.069, -31.329) in Western Australia
# 📦 Serves 43 ShipToIDs
# ⚖️ Total demand: 262,657 KG
# 🚚 Created 14 truck trips with enhanced consolidation
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 1: 3 stops, 19,712 KG
#       Route distance: 240.1 km, Mode: LTL, Cost: $362
#       Capacity utilization: 98.6%
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 2: 2 stops, 19,932 KG
#       Route distance: 74.5 km, Mode: LTL, Cost: $279
#       Capacity utilization: 99.7%
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 3: 2 stops, 19,768 KG
#       Route distance: 93.5 km, Mode: LTL, Cost: $289
#       Capacity utilization: 98.8%
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 4: 2 stops, 19,834 KG
#       Route distance: 80.3 km, Mode: LTL, Cost: $282
#       Capacity utilization: 99.2%
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 5: 4 stops, 19,244 KG
#       Route distance: 1633.7 km, Mode: LTL, Cost: $1,059
#       Capacity utilization: 96.2%
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 6: 3 stops, 19,592 KG
#       Route distance: 93.9 km, Mode: LTL, Cost: $289
#       Capacity utilization: 98.0%
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 7: 3 stops, 19,925 KG
#       Route distance: 1194.9 km, Mode: LTL, Cost: $840
#       Capacity utilization: 99.6%
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 8: 3 stops, 19,969 KG
#       Route distance: 231.2 km, Mode: LTL, Cost: $358
#       Capacity utilization: 99.8%
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 9: 3 stops, 19,637 KG
#       Route distance: 1380.9 km, Mode: LTL, Cost: $933
#       Capacity utilization: 98.2%
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 10: 3 stops, 17,253 KG
#       Route distance: 114.0 km, Mode: LTL, Cost: $299
#       Capacity utilization: 86.3%
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 11: 4 stops, 19,568 KG
#       Route distance: 95.1 km, Mode: LTL, Cost: $290
#       Capacity utilization: 97.8%
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 12: 4 stops, 19,653 KG
#       Route distance: 1715.0 km, Mode: LTL, Cost: $1,100
#       Capacity utilization: 98.3%
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 13: 4 stops, 19,228 KG
#       Route distance: 714.1 km, Mode: LTL, Cost: $599
#       Capacity utilization: 96.1%
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 14: 3 stops, 9,342 KG
#       Route distance: 307.7 km, Mode: LTL, Cost: $396
#       Capacity utilization: 46.7%
# 💰 RDC 1 total delivery cost: $7,375
#
# --- RDC 2 Analysis (New South Wales) ---
# 🏢 RDC 2: (151.795, -31.081) in New South Wales
# 📦 Serves 203 ShipToIDs
# ⚖️ Total demand: 767,647 KG
# ⚠️ Removing problematic shipment: 3211BR
# ⚠️ Removing problematic shipment: 3172BR
# 🚚 Created 38 truck trips with enhanced consolidation
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 1: 1 stops, 20,000 KG
#       Route distance: 636.1 km, Mode: LTL, Cost: $1,060
#       Capacity utilization: 100.0%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 2: 1 stops, 20,000 KG
#       Route distance: 640.2 km, Mode: LTL, Cost: $1,065
#       Capacity utilization: 100.0%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 3: 3 stops, 19,976 KG
#       Route distance: 373.5 km, Mode: LTL, Cost: $771
#       Capacity utilization: 99.9%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 4: 2 stops, 19,817 KG
#       Route distance: 453.0 km, Mode: LTL, Cost: $859
#       Capacity utilization: 99.1%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 5: 3 stops, 19,948 KG
#       Route distance: 1054.1 km, Mode: LTL, Cost: $1,520
#       Capacity utilization: 99.7%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 6: 2 stops, 19,941 KG
#       Route distance: 1042.4 km, Mode: LTL, Cost: $1,507
#       Capacity utilization: 99.7%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 7: 3 stops, 19,811 KG
#       Route distance: 966.6 km, Mode: LTL, Cost: $1,424
#       Capacity utilization: 99.1%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 8: 3 stops, 19,999 KG
#       Route distance: 1108.9 km, Mode: LTL, Cost: $1,580
#       Capacity utilization: 100.0%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 9: 3 stops, 19,997 KG
#       Route distance: 963.7 km, Mode: LTL, Cost: $1,420
#       Capacity utilization: 100.0%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 10: 3 stops, 19,970 KG
#       Route distance: 1044.6 km, Mode: LTL, Cost: $1,510
#       Capacity utilization: 99.8%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 11: 3 stops, 19,925 KG
#       Route distance: 1102.2 km, Mode: LTL, Cost: $1,573
#       Capacity utilization: 99.6%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 12: 3 stops, 19,970 KG
#       Route distance: 509.3 km, Mode: LTL, Cost: $921
#       Capacity utilization: 99.9%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 13: 3 stops, 19,777 KG
#       Route distance: 1106.4 km, Mode: LTL, Cost: $1,577
#       Capacity utilization: 98.9%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 14: 3 stops, 19,943 KG
#       Route distance: 1273.5 km, Mode: LTL, Cost: $1,761
#       Capacity utilization: 99.7%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 15: 3 stops, 19,973 KG
#       Route distance: 1125.3 km, Mode: LTL, Cost: $1,598
#       Capacity utilization: 99.9%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 16: 3 stops, 19,977 KG
#       Route distance: 466.7 km, Mode: LTL, Cost: $874
#       Capacity utilization: 99.9%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 17: 3 stops, 19,797 KG
#       Route distance: 1334.5 km, Mode: LTL, Cost: $1,828
#       Capacity utilization: 99.0%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 18: 4 stops, 19,978 KG
#       Route distance: 1257.1 km, Mode: LTL, Cost: $1,743
#       Capacity utilization: 99.9%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 19: 4 stops, 19,991 KG
#       Route distance: 1313.8 km, Mode: LTL, Cost: $1,806
#       Capacity utilization: 100.0%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 20: 4 stops, 19,907 KG
#       Route distance: 1202.4 km, Mode: LTL, Cost: $1,683
#       Capacity utilization: 99.5%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 21: 4 stops, 19,659 KG
#       Route distance: 1349.3 km, Mode: LTL, Cost: $1,845
#       Capacity utilization: 98.3%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 22: 5 stops, 19,998 KG
#       Route distance: 1300.9 km, Mode: LTL, Cost: $1,791
#       Capacity utilization: 100.0%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 23: 5 stops, 19,734 KG
#       Route distance: 1253.5 km, Mode: LTL, Cost: $1,739
#       Capacity utilization: 98.7%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 24: 6 stops, 19,969 KG
#       Route distance: 1271.8 km, Mode: LTL, Cost: $1,759
#       Capacity utilization: 99.8%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 25: 6 stops, 19,994 KG
#       Route distance: 1137.9 km, Mode: LTL, Cost: $1,612
#       Capacity utilization: 100.0%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 26: 7 stops, 19,961 KG
#       Route distance: 1657.7 km, Mode: LTL, Cost: $2,184
#       Capacity utilization: 99.8%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 27: 7 stops, 19,994 KG
#       Route distance: 1359.6 km, Mode: LTL, Cost: $1,856
#       Capacity utilization: 100.0%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 28: 7 stops, 19,596 KG
#       Route distance: 1377.3 km, Mode: LTL, Cost: $1,875
#       Capacity utilization: 98.0%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 29: 8 stops, 19,994 KG
#       Route distance: 1310.2 km, Mode: LTL, Cost: $1,802
#       Capacity utilization: 100.0%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 30: 8 stops, 19,847 KG
#       Route distance: 836.1 km, Mode: LTL, Cost: $1,280
#       Capacity utilization: 99.2%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 31: 9 stops, 19,976 KG
#       Route distance: 1538.9 km, Mode: LTL, Cost: $2,053
#       Capacity utilization: 99.9%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 32: 9 stops, 19,975 KG
#       Route distance: 1285.7 km, Mode: LTL, Cost: $1,775
#       Capacity utilization: 99.9%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 33: 9 stops, 19,171 KG
#       Route distance: 1198.5 km, Mode: LTL, Cost: $1,679
#       Capacity utilization: 95.9%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 34: 10 stops, 19,991 KG
#       Route distance: 1333.6 km, Mode: LTL, Cost: $1,827
#       Capacity utilization: 100.0%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 35: 11 stops, 19,997 KG
#       Route distance: 1492.8 km, Mode: LTL, Cost: $2,002
#       Capacity utilization: 100.0%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 36: 12 stops, 19,876 KG
#       Route distance: 1445.4 km, Mode: LTL, Cost: $1,950
#       Capacity utilization: 99.4%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 37: 13 stops, 19,537 KG
#       Route distance: 1444.7 km, Mode: LTL, Cost: $1,950
#       Capacity utilization: 97.7%
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 38: 10 stops, 11,342 KG
#       Route distance: 1562.0 km, Mode: LTL, Cost: $2,079
#       Capacity utilization: 56.7%
# 💰 RDC 2 total delivery cost: $61,138
#
# --- RDC 3 Analysis (Queensland) ---
# 🏢 RDC 3: (143.780, -18.629) in Queensland
# 📦 Serves 35 ShipToIDs
# ⚖️ Total demand: 100,511 KG
# 🚚 Created 6 truck trips with enhanced consolidation
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 1: 4 stops, 19,879 KG
#       Route distance: 1162.4 km, Mode: LTL, Cost: $575
#       Capacity utilization: 99.4%
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 2: 3 stops, 19,563 KG
#       Route distance: 3318.3 km, Mode: LTL, Cost: $1,222
#       Capacity utilization: 97.8%
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 3: 6 stops, 19,757 KG
#       Route distance: 3186.8 km, Mode: LTL, Cost: $1,183
#       Capacity utilization: 98.8%
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 4: 8 stops, 19,945 KG
#       Route distance: 4101.1 km, Mode: LTL, Cost: $1,457
#       Capacity utilization: 99.7%
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 5: 12 stops, 19,294 KG
#       Route distance: 4119.5 km, Mode: LTL, Cost: $1,463
#       Capacity utilization: 96.5%
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 6: 2 stops, 2,074 KG
#       Route distance: 331.5 km, Mode: LTL, Cost: $326
#       Capacity utilization: 10.4%
# 💰 RDC 3 total delivery cost: $6,226
#
# 🚛 Total Branch Delivery Cost K=4: $98,699
#
# 📦 Step 3: Handling Cost Calculation...
# 📦 RDC 0 (Victoria, Rural): 7,077 CBM × $7.0 = $49,536
# 📦 RDC 1 (Western Australia, Rural): 1,828 CBM × $7.0 = $12,799
# 📦 RDC 2 (New South Wales, Rural): 5,344 CBM × $7.0 = $37,407
# 📦 RDC 3 (Queensland, Rural): 700 CBM × $7.0 = $4,898
#
# 📦 Total Handling Cost K=4: $104,640
#
# 🏬 Step 4: Storage Cost Calculation with SRL...
# 📚 SRL Justification: Due to limited data on demand variability (σ_demand),
#     supplier lead times, and ordering costs for individual RDCs, we apply the
#     Square Root Law as a recognized method for estimating inventory changes.
#     Current DC inventory (14,898 CBM) includes both cycle and safety stock.
# 📊 SRL Calculation: 14,898 × √(4/1) = 29,796 CBM
# 📈 Inventory change: +100.0% vs baseline
# 🏬 RDC 0 (Victoria, Rural): 14,105 CBM × $21.0 = $296,211
#      Demand share: 47.3%
# 🏬 RDC 1 (Western Australia, Rural): 3,645 CBM × $21.0 = $76,535
#      Demand share: 12.2%
# 🏬 RDC 2 (New South Wales, Rural): 10,652 CBM × $21.0 = $223,683
#      Demand share: 35.7%
# 🏬 RDC 3 (Queensland, Rural): 1,395 CBM × $21.0 = $29,288
#      Demand share: 4.7%
#
# 🏬 Total Storage Cost K=4: $625,716
#
# 🔄 Step 5: Calculating Transfer Costs from Original DC to RDCs...
# 📍 Original DC: (151.1250996, -29.79165152) in New South Wales
# 🚛 Hub-and-Spoke model: Original DC supplies all RDCs
# Interceptor: 360.4
# Slope: 1.1
# Mode: LTL
# 🚛 Transfer to RDC 0 (Victoria):
#     Distance: 1041.6 km
#     Annual volume: 1,016,552 KG
#     Number of trips: 51
#     Cost per trip: $1506.20 (LTL)
#     Total transfer cost: $76,816
# Interceptor: 360.4
# Slope: 1.1
# Mode: LTL
# 🚛 Transfer to RDC 1 (Western Australia):
#     Distance: 3346.8 km
#     Annual volume: 262,657 KG
#     Number of trips: 14
#     Cost per trip: $4041.92 (LTL)
#     Total transfer cost: $56,587
# Interceptor: 360.4
# Slope: 1.1
# Mode: LTL
# 🚛 Transfer to RDC 2 (New South Wales):
#     Distance: 157.1 km
#     Annual volume: 767,647 KG
#     Number of trips: 39
#     Cost per trip: $533.20 (LTL)
#     Total transfer cost: $20,795
# Interceptor: 360.4
# Slope: 1.1
# Mode: LTL
# 🚛 Transfer to RDC 3 (Queensland):
#     Distance: 1446.6 km
#     Annual volume: 100,511 KG
#     Number of trips: 6
#     Cost per trip: $1951.63 (LTL)
#     Total transfer cost: $11,710
#
# 🔄 Total Transfer Cost K=4: $165,908
# 📊 Transfer Cost Justification:
#     • Hub-and-Spoke model: Original DC supplies all RDCs
#     • 20,000 KG capacity trucks used for transfers
#     • Cost curves applied based on DC state (NSW) and transfer distances
#     • 110 total transfer trips annually
#
# 💰 SCENARIO K=4 TOTAL COST BREAKDOWN:
#    🚛 Branch Delivery: $98,699 (9.9%)
#    📦 Handling: $104,640 (10.5%)
#    🏬 Storage: $625,716 (62.9%)
#    🔄 Transfer: $165,908 (16.7%)
#    🎯 TOTAL: $994,963
# ...
#       Route distance: 517.6 km, Mode: LTL, Cost: $382
#       Capacity utilization: 99.8%
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 6: 3 stops, 19,944 KG
#       Route distance: 268.2 km, Mode: LTL, Cost: $307
#       Capacity utilization: 99.7%
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 7: 3 stops, 19,921 KG
#       Route distance: 355.6 km, Mode: LTL, Cost: $333
#       Capacity utilization: 99.6%
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 8: 3 stops, 19,603 KG
#       Route distance: 402.7 km, Mode: LTL, Cost: $348
#       Capacity utilization: 98.0%
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 9: 4 stops, 19,986 KG
#       Route distance: 884.2 km, Mode: LTL, Cost: $492
#       Capacity utilization: 99.9%
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 10: 4 stops, 19,629 KG
#       Route distance: 143.2 km, Mode: LTL, Cost: $270
#       Capacity utilization: 98.1%
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 11: 4 stops, 19,074 KG
#       Route distance: 608.6 km, Mode: LTL, Cost: $409
#       Capacity utilization: 95.4%
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 12: 5 stops, 19,109 KG
#       Route distance: 919.4 km, Mode: LTL, Cost: $503
#       Capacity utilization: 95.5%
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 13: 6 stops, 19,987 KG
#       Route distance: 223.3 km, Mode: LTL, Cost: $294
#       Capacity utilization: 99.9%
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 14: 7 stops, 19,916 KG
#       Route distance: 778.4 km, Mode: LTL, Cost: $460
#       Capacity utilization: 99.6%
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 15: 8 stops, 19,989 KG
#       Route distance: 881.5 km, Mode: LTL, Cost: $491
#       Capacity utilization: 99.9%
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 16: 9 stops, 19,992 KG
#       Route distance: 1100.7 km, Mode: LTL, Cost: $557
#       Capacity utilization: 100.0%
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 17: 11 stops, 19,960 KG
#       Route distance: 1009.9 km, Mode: LTL, Cost: $530
#       Capacity utilization: 99.8%
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 18: 8 stops, 11,765 KG
#       Route distance: 813.4 km, Mode: LTL, Cost: $471
#       Capacity utilization: 58.8%
# 💰 RDC 2 total delivery cost: $6,826
#
# --- RDC 3 Analysis (Victoria) ---
# 🏢 RDC 3: (145.215, -38.048) in Victoria
# 📦 Serves 151 ShipToIDs
# ⚖️ Total demand: 807,264 KG
# ⚠️ Removing problematic shipment: 4795BR
# ⚠️ Removing problematic shipment: 4880BR
# ⚠️ Removing problematic shipment: 4217BR
# ⚠️ Removing problematic shipment: 4048BR
# 🚚 Created 34 truck trips with enhanced consolidation
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 1: 1 stops, 20,000 KG
#       Route distance: 102.2 km, Mode: LTL, Cost: $355
#       Capacity utilization: 100.0%
# Intercept: 198.4
# Slope: 1.0
# Mode: FTL
#    Truck 2: 1 stops, 20,000 KG
#       Route distance: 6.2 km, Mode: FTL, Cost: $205
#       Capacity utilization: 100.0%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 3: 1 stops, 20,000 KG
#       Route distance: 268.6 km, Mode: LTL, Cost: $389
#       Capacity utilization: 100.0%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 4: 1 stops, 20,000 KG
#       Route distance: 98.5 km, Mode: LTL, Cost: $354
#       Capacity utilization: 100.0%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 5: 2 stops, 19,976 KG
#       Route distance: 886.5 km, Mode: LTL, Cost: $512
#       Capacity utilization: 99.9%
# Intercept: 198.4
# Slope: 1.0
# Mode: FTL
#    Truck 6: 2 stops, 19,995 KG
#       Route distance: 27.6 km, Mode: FTL, Cost: $226
#       Capacity utilization: 100.0%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 7: 2 stops, 19,968 KG
#       Route distance: 419.5 km, Mode: LTL, Cost: $419
#       Capacity utilization: 99.8%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 8: 3 stops, 19,952 KG
#       Route distance: 332.3 km, Mode: LTL, Cost: $401
#       Capacity utilization: 99.8%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 9: 2 stops, 19,915 KG
#       Route distance: 310.4 km, Mode: LTL, Cost: $397
#       Capacity utilization: 99.6%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 10: 2 stops, 19,996 KG
#       Route distance: 187.5 km, Mode: LTL, Cost: $372
#       Capacity utilization: 100.0%
# Intercept: 198.4
# Slope: 1.0
# Mode: FTL
#    Truck 11: 2 stops, 19,982 KG
#       Route distance: 18.6 km, Mode: FTL, Cost: $217
#       Capacity utilization: 99.9%
# Intercept: 198.4
# Slope: 1.0
# Mode: FTL
#    Truck 12: 2 stops, 19,718 KG
#       Route distance: 56.3 km, Mode: FTL, Cost: $255
#       Capacity utilization: 98.6%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 13: 2 stops, 19,728 KG
#       Route distance: 81.5 km, Mode: LTL, Cost: $351
#       Capacity utilization: 98.6%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 14: 2 stops, 19,988 KG
#       Route distance: 608.9 km, Mode: LTL, Cost: $457
#       Capacity utilization: 99.9%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 15: 3 stops, 19,970 KG
#       Route distance: 559.2 km, Mode: LTL, Cost: $447
#       Capacity utilization: 99.9%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 16: 3 stops, 19,931 KG
#       Route distance: 472.7 km, Mode: LTL, Cost: $429
#       Capacity utilization: 99.7%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 17: 3 stops, 19,999 KG
#       Route distance: 81.1 km, Mode: LTL, Cost: $351
#       Capacity utilization: 100.0%
# Intercept: 198.4
# Slope: 1.0
# Mode: FTL
#    Truck 18: 3 stops, 19,760 KG
#       Route distance: 56.9 km, Mode: FTL, Cost: $255
#       Capacity utilization: 98.8%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 19: 3 stops, 19,717 KG
#       Route distance: 301.8 km, Mode: LTL, Cost: $395
#       Capacity utilization: 98.6%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 20: 4 stops, 19,986 KG
#       Route distance: 265.5 km, Mode: LTL, Cost: $388
#       Capacity utilization: 99.9%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 21: 4 stops, 19,983 KG
#       Route distance: 306.8 km, Mode: LTL, Cost: $396
#       Capacity utilization: 99.9%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 22: 4 stops, 19,962 KG
#       Route distance: 425.0 km, Mode: LTL, Cost: $420
#       Capacity utilization: 99.8%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 23: 5 stops, 19,984 KG
#       Route distance: 333.2 km, Mode: LTL, Cost: $401
#       Capacity utilization: 99.9%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 24: 5 stops, 19,988 KG
#       Route distance: 763.8 km, Mode: LTL, Cost: $488
#       Capacity utilization: 99.9%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 25: 5 stops, 19,471 KG
#       Route distance: 170.8 km, Mode: LTL, Cost: $369
#       Capacity utilization: 97.4%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 26: 5 stops, 19,387 KG
#       Route distance: 141.1 km, Mode: LTL, Cost: $363
#       Capacity utilization: 96.9%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 27: 7 stops, 19,998 KG
#       Route distance: 1224.2 km, Mode: LTL, Cost: $580
#       Capacity utilization: 100.0%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 28: 7 stops, 19,939 KG
#       Route distance: 1020.7 km, Mode: LTL, Cost: $539
#       Capacity utilization: 99.7%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 29: 7 stops, 19,374 KG
#       Route distance: 156.0 km, Mode: LTL, Cost: $366
#       Capacity utilization: 96.9%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 30: 8 stops, 19,999 KG
#       Route distance: 1470.7 km, Mode: LTL, Cost: $629
#       Capacity utilization: 100.0%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 31: 9 stops, 19,987 KG
#       Route distance: 811.1 km, Mode: LTL, Cost: $497
#       Capacity utilization: 99.9%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 32: 10 stops, 19,988 KG
#       Route distance: 1826.5 km, Mode: LTL, Cost: $700
#       Capacity utilization: 99.9%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 33: 13 stops, 19,974 KG
#       Route distance: 658.7 km, Mode: LTL, Cost: $467
#       Capacity utilization: 99.9%
# Intercept: 334.8
# Slope: 0.2
# Mode: LTL
#    Truck 34: 18 stops, 19,892 KG
#       Route distance: 1784.7 km, Mode: LTL, Cost: $692
#       Capacity utilization: 99.5%
# 💰 RDC 3 total delivery cost: $14,081
#
# --- RDC 4 Analysis (Queensland) ---
# 🏢 RDC 4: (146.099, -19.359) in Queensland
# 📦 Serves 23 ShipToIDs
# ⚖️ Total demand: 60,808 KG
# 🚚 Created 4 truck trips with enhanced consolidation
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 1: 4 stops, 19,966 KG
#       Route distance: 1000.0 km, Mode: LTL, Cost: $527
#       Capacity utilization: 99.8%
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 2: 6 stops, 19,320 KG
#       Route distance: 1946.3 km, Mode: LTL, Cost: $811
#       Capacity utilization: 96.6%
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 3: 11 stops, 19,448 KG
#       Route distance: 3029.3 km, Mode: LTL, Cost: $1,135
#       Capacity utilization: 97.2%
# Intercept: 226.7
# Slope: 0.3
# Mode: LTL
#    Truck 4: 2 stops, 2,074 KG
#       Route distance: 269.1 km, Mode: LTL, Cost: $307
#       Capacity utilization: 10.4%
# 💰 RDC 4 total delivery cost: $2,780
#
# --- RDC 5 Analysis (Western Australia) ---
# 🏢 RDC 5: (117.441, -20.623) in Western Australia
# 📦 Serves 3 ShipToIDs
# ⚖️ Total demand: 21,331 KG
# 🚚 Created 2 truck trips with enhanced consolidation
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 1: 2 stops, 16,095 KG
#       Route distance: 244.5 km, Mode: LTL, Cost: $364
#       Capacity utilization: 80.5%
# Intercept: 242.2
# Slope: 0.5
# Mode: LTL
#    Truck 2: 1 stops, 5,237 KG
#       Route distance: 126.8 km, Mode: LTL, Cost: $306
#       Capacity utilization: 26.2%
# 💰 RDC 5 total delivery cost: $670
#
# --- RDC 6 Analysis (South Australia) ---
# 🏢 RDC 6: (138.868, -34.761) in South Australia
# 📦 Serves 39 ShipToIDs
# ⚖️ Total demand: 142,535 KG
# 🚚 Created 8 truck trips with enhanced consolidation
# ⚠️ Using NSW fallback for South Australia
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 1: 1 stops, 19,824 KG
#       Route distance: 62.3 km, Mode: LTL, Cost: $429
#       Capacity utilization: 99.1%
# ⚠️ Using NSW fallback for South Australia
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 2: 3 stops, 19,968 KG
#       Route distance: 253.9 km, Mode: LTL, Cost: $640
#       Capacity utilization: 99.8%
# ⚠️ Using NSW fallback for South Australia
# Intercept: 225.2
# Slope: 0.9
# Mode: FTL
#    Truck 3: 2 stops, 19,910 KG
#       Route distance: 54.5 km, Mode: FTL, Cost: $274
#       Capacity utilization: 99.5%
# ⚠️ Using NSW fallback for South Australia
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 4: 4 stops, 19,969 KG
#       Route distance: 396.8 km, Mode: LTL, Cost: $797
#       Capacity utilization: 99.8%
# ⚠️ Using NSW fallback for South Australia
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 5: 7 stops, 19,980 KG
#       Route distance: 502.0 km, Mode: LTL, Cost: $913
#       Capacity utilization: 99.9%
# ⚠️ Using NSW fallback for South Australia
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 6: 8 stops, 19,865 KG
#       Route distance: 785.4 km, Mode: LTL, Cost: $1,224
#       Capacity utilization: 99.3%
# ⚠️ Using NSW fallback for South Australia
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 7: 11 stops, 19,674 KG
#       Route distance: 762.4 km, Mode: LTL, Cost: $1,199
#       Capacity utilization: 98.4%
# ⚠️ Using NSW fallback for South Australia
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 8: 3 stops, 3,346 KG
#       Route distance: 363.8 km, Mode: LTL, Cost: $761
#       Capacity utilization: 16.7%
# 💰 RDC 6 total delivery cost: $6,236
#
# --- RDC 7 Analysis (South Australia) ---
# 🏢 RDC 7: (131.109, -12.734) in South Australia
# 📦 Serves 7 ShipToIDs
# ⚖️ Total demand: 22,243 KG
# 🚚 Created 2 truck trips with enhanced consolidation
# ⚠️ Using NSW fallback for South Australia
# Intercept: 225.2
# Slope: 0.9
# Mode: FTL
#    Truck 1: 5 stops, 19,871 KG
#       Route distance: 54.8 km, Mode: FTL, Cost: $275
#       Capacity utilization: 99.4%
# ⚠️ Using NSW fallback for South Australia
# Intercept: 360.4
# Slope: 1.1
# Mode: LTL
#    Truck 2: 2 stops, 2,371 KG
#       Route distance: 295.0 km, Mode: LTL, Cost: $685
#       Capacity utilization: 11.9%
# 💰 RDC 7 total delivery cost: $959
#
# 🚛 Total Branch Delivery Cost K=8: $57,282
#
# 📦 Step 3: Handling Cost Calculation...
# 📦 RDC 0 (New South Wales, Urban): 3,510 CBM × $11.0 = $38,608
# 📦 RDC 1 (Western Australia, Urban): 1,680 CBM × $11.0 = $18,480
# 📦 RDC 2 (Queensland, Urban): 2,420 CBM × $11.0 = $26,623
# 📦 RDC 3 (Victoria, Urban): 5,620 CBM × $11.0 = $61,816
# 📦 RDC 4 (Queensland, Rural): 423 CBM × $7.0 = $2,963
# 📦 RDC 5 (Western Australia, Rural): 148 CBM × $7.0 = $1,039
# 📦 RDC 6 (South Australia, Rural): 992 CBM × $7.0 = $6,946
# 📦 RDC 7 (South Australia, Rural): 155 CBM × $7.0 = $1,084
#
# 📦 Total Handling Cost K=8: $157,559
#
# 🏬 Step 4: Storage Cost Calculation with SRL...
# 📚 SRL Justification: Due to limited data on demand variability (σ_demand),
#     supplier lead times, and ordering costs for individual RDCs, we apply the
#     Square Root Law as a recognized method for estimating inventory changes.
#     Current DC inventory (14,898 CBM) includes both cycle and safety stock.
# 📊 SRL Calculation: 14,898 × √(8/1) = 42,138 CBM
# 📈 Inventory change: +182.8% vs baseline
# 🏬 RDC 0 (New South Wales, Urban): 9,894 CBM × $33.0 = $326,492
#      Demand share: 23.5%
# 🏬 RDC 1 (Western Australia, Urban): 4,736 CBM × $33.0 = $156,273
#      Demand share: 11.2%
# 🏬 RDC 2 (Queensland, Urban): 6,822 CBM × $33.0 = $225,140
#      Demand share: 16.2%
# 🏬 RDC 3 (Victoria, Urban): 15,841 CBM × $33.0 = $522,753
#      Demand share: 37.6%
# 🏬 RDC 4 (Queensland, Rural): 1,193 CBM × $21.0 = $25,058
#      Demand share: 2.8%
# 🏬 RDC 5 (Western Australia, Rural): 419 CBM × $21.0 = $8,790
#      Demand share: 1.0%
# 🏬 RDC 6 (South Australia, Rural): 2,797 CBM × $21.0 = $58,736
#      Demand share: 6.6%
# 🏬 RDC 7 (South Australia, Rural): 436 CBM × $21.0 = $9,166
#      Demand share: 1.0%
#
# 🏬 Total Storage Cost K=8: $1,332,408
#
# 🔄 Step 5: Calculating Transfer Costs from Original DC to RDCs...
# 📍 Original DC: (151.1250996, -29.79165152) in New South Wales
# 🚛 Hub-and-Spoke model: Original DC supplies all RDCs
# Interceptor: 360.4
# Slope: 1.1
# Mode: LTL
# 🚛 Transfer to RDC 0 (New South Wales):
#     Distance: 433.5 km
#     Annual volume: 504,187 KG
#     Number of trips: 26
#     Cost per trip: $837.23 (LTL)
#     Total transfer cost: $21,768
# Interceptor: 360.4
# Slope: 1.1
# Mode: LTL
# 🚛 Transfer to RDC 1 (Western Australia):
#     Distance: 3347.8 km
#     Annual volume: 241,326 KG
#     Number of trips: 13
#     Cost per trip: $4042.94 (LTL)
#     Total transfer cost: $52,558
# Interceptor: 360.4
# Slope: 1.1
# Mode: LTL
# 🚛 Transfer to RDC 2 (Queensland):
#     Distance: 321.1 km
#     Annual volume: 347,674 KG
#     Number of trips: 18
#     Cost per trip: $713.58 (LTL)
#     Total transfer cost: $12,844
# Interceptor: 360.4
# Slope: 1.1
# Mode: LTL
# 🚛 Transfer to RDC 3 (Victoria):
#     Distance: 1067.2 km
#     Annual volume: 807,264 KG
#     Number of trips: 41
#     Cost per trip: $1534.34 (LTL)
#     Total transfer cost: $62,908
# Interceptor: 360.4
# Slope: 1.1
# Mode: LTL
# 🚛 Transfer to RDC 4 (Queensland):
#     Distance: 1266.0 km
#     Annual volume: 60,808 KG
#     Number of trips: 4
#     Cost per trip: $1752.99 (LTL)
#     Total transfer cost: $7,012
# Interceptor: 360.4
# Slope: 1.1
# Mode: LTL
# 🚛 Transfer to RDC 5 (Western Australia):
#     Distance: 3524.3 km
#     Annual volume: 21,331 KG
#     Number of trips: 2
#     Cost per trip: $4237.12 (LTL)
#     Total transfer cost: $8,474
# Interceptor: 360.4
# Slope: 1.1
# Mode: LTL
# 🚛 Transfer to RDC 6 (South Australia):
#     Distance: 1276.7 km
#     Annual volume: 142,535 KG
#     Number of trips: 8
#     Cost per trip: $1764.72 (LTL)
#     Total transfer cost: $14,118
# Interceptor: 360.4
# Slope: 1.1
# Mode: LTL
# 🚛 Transfer to RDC 7 (South Australia):
#     Distance: 2801.3 km
#     Annual volume: 22,243 KG
#     Number of trips: 2
#     Cost per trip: $3441.83 (LTL)
#     Total transfer cost: $6,884
#
# 🔄 Total Transfer Cost K=8: $186,566
# 📊 Transfer Cost Justification:
#     • Hub-and-Spoke model: Original DC supplies all RDCs
#     • 20,000 KG capacity trucks used for transfers
#     • Cost curves applied based on DC state (NSW) and transfer distances
#     • 114 total transfer trips annually
#
# 💰 SCENARIO K=8 TOTAL COST BREAKDOWN:
#    🚛 Branch Delivery: $57,282 (3.3%)
#    📦 Handling: $157,559 (9.1%)
#    🏬 Storage: $1,332,408 (76.8%)
#    🔄 Transfer: $186,566 (10.8%)
#    🎯 TOTAL: $1,733,815
#    💾 Savings vs Baseline: $1,344,612 (+43.7%)

# %% [markdown]
# ---
# # COMPREHENSIVE VISUALIZATION WITH PLOTLY

# %%
print(f"\n" + "="*80)
print("📊 CREATING COMPREHENSIVE PLOTLY VISUALIZATIONS")
print("="*80)

# Prepare scenario comparison data
scenario_data = []
for K, results in all_scenario_results.items():
    scenario_data.append({
        'K': K,
        'Total_Cost': results['total_cost'],
        'Branch_Delivery': results['branch_delivery_cost'],
        'Handling': results['handling_cost'],
        'Storage': results['storage_cost'],
        'Transfer': results['transfer_cost'],
        'Savings_vs_Baseline': results['savings_vs_baseline'],
        'Savings_Percentage': results['savings_percentage']
    })

scenario_df = pd.DataFrame(scenario_data)
scenario_df
# Out:
# ================================================================================
# 📊 CREATING COMPREHENSIVE PLOTLY VISUALIZATIONS
# ================================================================================
#    K    Total_Cost  Branch_Delivery       Handling       Storage  \
# 0  2  9.621547e+05    273904.967245  104640.443654  4.424480e+05
# 1  3  9.701880e+05    156336.506350  104640.443654  5.418860e+05
# 2  4  9.949627e+05     98698.686109  104640.443654  6.257160e+05
# 3  5  1.227106e+06     63402.175518  128485.644164  8.589884e+05
# 4  6  1.496213e+06     61350.909272  150885.714232  1.105023e+06
# 5  7  1.645019e+06     59056.923702  157559.469165  1.246353e+06
# 6  8  1.733815e+06     57281.508299  157559.469165  1.332408e+06
#
#         Transfer  Savings_vs_Baseline  Savings_Percentage
# 0  141161.228423         2.116272e+06           68.745250
# 1  167325.139265         2.108239e+06           68.484293
# 2  165907.608597         2.083464e+06           67.679508
# 3  176230.215983         1.851321e+06           60.138524
# 4  178953.194830         1.582214e+06           51.396829
# 5  182049.292995         1.433408e+06           46.562997
# 6  186566.419423         1.344612e+06           43.678532

# %%
# nhân 5 lên
scenario_df['Branch_Delivery'] *= 5
scenario_df['Transfer'] *= 5
scenario_df['Handling'] *= 5
scenario_df['Total_Cost'] = scenario_df['Branch_Delivery'] + scenario_df['Handling'] + scenario_df['Storage'] + scenario_df['Transfer']
scenario_df['Savings_vs_Baseline'] = baseline_total_cost - scenario_df['Total_Cost']
scenario_df['Savings_Percentage'] = scenario_df['Savings_vs_Baseline'] / baseline_total_cost * 100

# %% [markdown]
# ---
# ## 1. Enhanced Stacked Bar Chart with Transfer costs

# %%
fig_cost_breakdown = go.Figure()

fig_cost_breakdown.add_trace(go.Bar(
    name='Branch Delivery',
    x=scenario_df['K'],
    y=scenario_df['Branch_Delivery'],
    marker_color='#FF6B6B',
    text=[f'${val:,.0f}' for val in scenario_df['Branch_Delivery']],
    textposition='inside',
    textfont_color='white'
))

fig_cost_breakdown.add_trace(go.Bar(
    name='Handling',
    x=scenario_df['K'],
    y=scenario_df['Handling'],
    marker_color='#4ECDC4',
    text=[f'${val:,.0f}' for val in scenario_df['Handling']],
    textposition='inside',
    textfont_color='white'
))

fig_cost_breakdown.add_trace(go.Bar(
    name='Storage',
    x=scenario_df['K'],
    y=scenario_df['Storage'],
    marker_color='#45B7D1',
    text=[f'${val:,.0f}' for val in scenario_df['Storage']],
    textposition='inside',
    textfont_color='white'
))

fig_cost_breakdown.add_trace(go.Bar(
    name='Transfer',
    x=scenario_df['K'],
    y=scenario_df['Transfer'],
    marker_color='#96CEB4',
    text=[f'${val:,.0f}' for val in scenario_df['Transfer']],
    textposition='inside',
    textfont_color='white'
))

# Add baseline reference line
fig_cost_breakdown.add_hline(
    y=baseline_total_cost,
    line_dash="dash",
    line_color="red",
    line_width=3,
    annotation_text=f"Baseline: ${baseline_total_cost:,.0f}",
    annotation_position="top right"
)

fig_cost_breakdown.update_layout(
    title='<b>Annual Cost Breakdown by RDC Scenarios (Including Transfer Costs)</b>',
    xaxis_title='Number of RDCs (K)',
    yaxis_title='Annual Cost (AUD)',
    barmode='stack',
    height=600,
    font=dict(size=12)
)

fig_cost_breakdown.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="732e0f13-a423-47bb-b5ba-4e3e940c1ede" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("732e0f13-a423-47bb-b5ba-4e3e940c1ede")) {                    Plotly.newPlot(                        "732e0f13-a423-47bb-b5ba-4e3e940c1ede",                        [{"marker":{"color":"#FF6B6B"},"name":"Branch Delivery","text":["$1,369,525","$781,683","$493,493","$317,011","$306,755","$295,285","$286,408"],"textfont":{"color":"white"},"textposition":"inside","x":[2,3,4,5,6,7,8],"y":[1369524.8362230442,781682.5317501103,493493.4305472296,317010.87759132055,306754.54635754885,295284.6185116232,286407.54149620835],"type":"bar"},{"marker":{"color":"#4ECDC4"},"name":"Handling","text":["$523,202","$523,202","$523,202","$642,428","$754,429","$787,797","$787,797"],"textfont":{"color":"white"},"textposition":"inside","x":[2,3,4,5,6,7,8],"y":[523202.2182704206,523202.21827042056,523202.2182704207,642428.2208220108,754428.5711579501,787797.3458263389,787797.3458263389],"type":"bar"},{"marker":{"color":"#45B7D1"},"name":"Storage","text":["$442,448","$541,886","$625,716","$858,988","$1,105,023","$1,246,353","$1,332,408"],"textfont":{"color":"white"},"textposition":"inside","x":[2,3,4,5,6,7,8],"y":[442448.026696922,541885.951554384,625716.0000000002,858988.4033431142,1105023.312966952,1246353.4532840673,1332407.8871461551],"type":"bar"},{"marker":{"color":"#96CEB4"},"name":"Transfer","text":["$705,806","$836,626","$829,538","$881,151","$894,766","$910,246","$932,832"],"textfont":{"color":"white"},"textposition":"inside","x":[2,3,4,5,6,7,8],"y":[705806.1421147983,836625.6963264567,829538.0429841105,881151.0799152235,894765.9741490111,910246.4649730839,932832.0971138637],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.777777 ...

# %% [markdown]
# ---
# ## 2. Savings Analysis

# %%
fig_savings = go.Figure()

colors = ['green' if x > 0 else 'red' for x in scenario_df['Savings_vs_Baseline']]

fig_savings.add_trace(go.Bar(
    x=scenario_df['K'],
    y=scenario_df['Savings_vs_Baseline'],
    marker_color=colors,
    text=[f'${val:,.0f}<br>({pct:+.1f}%)' for val, pct in
          zip(scenario_df['Savings_vs_Baseline'], scenario_df['Savings_Percentage'])],
    textposition='outside',
    name='Cost Savings vs Baseline'
))

fig_savings.add_hline(y=0, line_dash="solid", line_color="black", line_width=1)

fig_savings.update_layout(
    title='<b>Cost Savings vs Baseline by RDC Scenarios</b>',
    xaxis_title='Number of RDCs (K)',
    yaxis_title='Savings (AUD)',
    height=500
)

fig_savings.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="eea34154-9882-4dad-be57-460a3e723b6c" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eea34154-9882-4dad-be57-460a3e723b6c")) {                    Plotly.newPlot(                        "eea34154-9882-4dad-be57-460a3e723b6c",                        [{"marker":{"color":["green","green","green","green","green","red","red"]},"name":"Cost Savings vs Baseline","text":["$37,446\u003cbr\u003e(+1.2%)","$395,031\u003cbr\u003e(+12.8%)","$606,477\u003cbr\u003e(+19.7%)","$378,848\u003cbr\u003e(+12.3%)","$17,455\u003cbr\u003e(+0.6%)","$-161,255\u003cbr\u003e(-5.2%)","$-261,018\u003cbr\u003e(-8.5%)"],"textposition":"outside","x":[2,3,4,5,6,7,8],"y":[37445.776694814675,395030.60209862795,606477.3081982387,378848.41832833085,17454.595368538052,-161254.88259511348,-261017.87158256583],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6", ...

# %% [markdown]
# ---
# ## 3. Transfer Cost Analysis

# %%
fig_transfer_analysis = go.Figure()

transfer_costs = [results['transfer_cost'] for results in all_scenario_results.values()]
transfer_trips = []
for results in all_scenario_results.values():
    total_trips = sum(detail['num_trips'] for detail in results.get('transfer_details', []))
    transfer_trips.append(total_trips)

fig_transfer_analysis.add_trace(go.Scatter(
    x=scenario_df['K'],
    y=transfer_costs,
    mode='lines+markers',
    name='Transfer Cost',
    line=dict(width=3, color='green'),
    marker=dict(size=10),
    yaxis='y'
))

fig_transfer_analysis.add_trace(go.Scatter(
    x=scenario_df['K'],
    y=transfer_trips,
    mode='lines+markers',
    name='Transfer Trips',
    line=dict(width=2, color='orange'),
    marker=dict(size=8),
    yaxis='y2'
))

fig_transfer_analysis.update_layout(
    title='<b>Transfer Cost and Trip Analysis by Number of RDCs</b>',
    xaxis_title='Number of RDCs (K)',
    yaxis=dict(title='Transfer Cost (AUD)', side='left'),
    yaxis2=dict(title='Number of Transfer Trips', side='right', overlaying='y'),
    height=500
)

fig_transfer_analysis.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="200f2bbd-b83a-4d42-9a5f-5479ea26d9a0" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("200f2bbd-b83a-4d42-9a5f-5479ea26d9a0")) {                    Plotly.newPlot(                        "200f2bbd-b83a-4d42-9a5f-5479ea26d9a0",                        [{"line":{"color":"green","width":3},"marker":{"size":10},"mode":"lines+markers","name":"Transfer Cost","x":[2,3,4,5,6,7,8],"y":[141161.22842295966,167325.13926529133,165907.6085968221,176230.2159830447,178953.1948298022,182049.2929946168,186566.41942277274],"yaxis":"y","type":"scatter"},{"line":{"color":"orange","width":2},"marker":{"size":8},"mode":"lines+markers","name":"Transfer Trips","x":[2,3,4,5,6,7,8],"y":[108,109,110,111,112,113,114],"yaxis":"y2","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity": ...

# %% [markdown]
# ---
# ## 4. Network Maps for Each Scenario

# %%
for K, results in all_scenario_results.items():
    print(f"🗺️ Creating network map for K={K} scenario...")

    df_scenario = results['scenario_data']
    rdc_centers = results['rdc_centers']
    rdc_states = results['rdc_states']
    rdc_location_types = results['rdc_location_types']

    fig_network = go.Figure()

    # Plot original DC
    fig_network.add_trace(go.Scatter(
        x=[lon_ref],
        y=[lat_ref],
        mode='markers+text',
        marker=dict(symbol='diamond', size=25, color='red',
                   line=dict(width=3, color='white')),
        text=['Original DC<br>NSW'],
        textposition="top center",
        name='Original DC',
        hovertemplate='Original DC (NSW)<extra></extra>'
    ))

    # Plot RDCs
    fig_network.add_trace(go.Scatter(
        x=rdc_centers[:, 0],
        y=rdc_centers[:, 1],
        mode='markers+text',
        marker=dict(symbol='star', size=20, color='blue',
                   line=dict(width=2, color='white')),
        text=[f'RDC {i}<br>{rdc_states[i]}<br>({rdc_location_types[i]})' for i in range(K)],
        textposition="bottom center",
        name='RDCs',
        hovertemplate='%{text}<extra></extra>'
    ))

    # Plot transfer connections
    for i, center in enumerate(rdc_centers):
        fig_network.add_trace(go.Scatter(
            x=[lon_ref, center[0]],
            y=[lat_ref, center[1]],
            mode='lines',
            line=dict(color='red', width=2, dash='dash'),
            name=f'Transfer to RDC {i}',
            showlegend=False,
            hovertemplate='Transfer route<extra></extra>'
        ))

    # Plot ShipToIDs by cluster
    colors = px.colors.qualitative.Set1
    for rdc_id in range(K):
        cluster_data = df_scenario[df_scenario['RDC_Assignment'] == rdc_id]

        if len(cluster_data) > 0:
            fig_network.add_trace(go.Scatter(
                x=cluster_data['Longitude'],
                y=cluster_data['Latitude'],
                mode='markers',
                marker=dict(
                    color=colors[rdc_id % len(colors)],
                    size=np.clip(cluster_data['Annual_KG_Demand_ShipTo']/2000, 4, 15),
                    opacity=0.7,
                    line=dict(width=1, color='white')
                ),
                text=[f"<b>{row['ShipToID']}</b><br>RDC: {row['RDC_Assignment']} ({rdc_states[row['RDC_Assignment']]})<br>KG: {row['Annual_KG_Demand_ShipTo']:,.0f}"
                      for _, row in cluster_data.iterrows()],
                hovertemplate='%{text}<extra></extra>',
                name=f'RDC {rdc_id} Zone ({len(cluster_data)} locations)',
                showlegend=True
            ))

    savings = results['savings_vs_baseline']
    fig_network.update_layout(
        title=f'<b>Hub-and-Spoke Network: K={K} RDCs</b><br>' +
              f'Total Cost: ${results["total_cost"]:,.0f} | ' +
              f'Transfer Cost: ${results["transfer_cost"]:,.0f} | ' +
              f'Savings: ${savings:,.0f} ({results["savings_percentage"]:+.1f}%)',
        xaxis_title='Longitude (°E)',
        yaxis_title='Latitude (°S)',
        height=700,
        showlegend=True
    )

    fig_network.show()
# Out:
# 🗺️ Creating network map for K=2 scenario...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="61559b3a-aac4-4716-8ca8-fb00754255af" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("61559b3a-aac4-4716-8ca8-fb00754255af")) {                    Plotly.newPlot(                        "61559b3a-aac4-4716-8ca8-fb00754255af",                        [{"hovertemplate":"Original DC (NSW)\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"red","line":{"color":"white","width":3},"size":25,"symbol":"diamond"},"mode":"markers+text","name":"Original DC","text":["Original DC\u003cbr\u003eNSW"],"textposition":"top center","x":[151.1250996],"y":[-29.79165152],"type":"scatter"},{"hovertemplate":"%{text}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"blue","line":{"color":"white","width":2},"size":20,"symbol":"star"},"mode":"markers+text","name":"RDCs","text":["RDC 0\u003cbr\u003eNew South Wales\u003cbr\u003e(Rural)","RDC 1\u003cbr\u003eWestern Australia\u003cbr\u003e(Rural)"],"textposition":"bottom center","x":[147.97512807172413,118.4823742],"y":[-33.283163323609195,-28.6272283027451],"type":"scatter"},{"hovertemplate":"Transfer route\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"red","dash":"dash","width":2},"mode":"lines","name":"Transfer to RDC 0","showlegend":false,"x":[151.1250996,147.97512807172413],"y":[-29.79165152,-33.283163323609195],"type":"scatter"},{"hovertemplate":"Transfer route\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"red","dash":"dash","width":2},"mode":"lines","name":"Transfer to RDC 1","showlegend":false,"x":[151.1250996,118.4823742],"y":[-29.79165152,-28.6272283027451],"type":"scatter"},{"hovertemplate":"%{text}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"rgb(228,26,28)","line":{"color":"white","width":1},"opacity":0.7,"size":[4.0,4.0,9.91859602,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,7.80118054582022,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.8165445,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.393268,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,13.886756383595198,4.0,4.0,4.0,4.0,4.293437643927501,4.0,4.0,4.033082039789499,5.0343033,4.0,4.341317,4.0,4.0,4.0,4.7544884000000005,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,15.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.3329855,4.0,4.0,5.64111639276022,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,10.032752866700001,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,15.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,15.0,7.734414749850301,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,15.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,9.211938752623501,4.0,4.0,4.0,4.0,4.0,4.0,9.865438908696,4.0,5.4702682667,4.0,4.0,8.9825162344068,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,5.492947004138,4.0,6.4797462096842,4.0,4.0,4.0,5.3971232,8.2941340295789,4.0,4.0,4.0,5.08302881,4.0,6.25820957,6.568481420000001,4.0,4.0,4.0,4.2229463,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.4746776,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.3948719,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.2811739,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,5.0709741,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,6.050415967439,4.0,4.0,4.0,4.0,4.0,4.0,5.154149823506,4.528308999999999,6.2234496,4.0,4.0,6.0180514,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.337397200000001,4.0,4.0,4.0,4.0,4.0,4.0,4.0,9.9121989,4.0,4.286540462654 ...
# 🗺️ Creating network map for K=3 scenario...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9ee22543-81f6-4c4a-b289-f1a6876eb3ab" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9ee22543-81f6-4c4a-b289-f1a6876eb3ab")) {                    Plotly.newPlot(                        "9ee22543-81f6-4c4a-b289-f1a6876eb3ab",                        [{"hovertemplate":"Original DC (NSW)\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"red","line":{"color":"white","width":3},"size":25,"symbol":"diamond"},"mode":"markers+text","name":"Original DC","text":["Original DC\u003cbr\u003eNSW"],"textposition":"top center","x":[151.1250996],"y":[-29.79165152],"type":"scatter"},{"hovertemplate":"%{text}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"blue","line":{"color":"white","width":2},"size":20,"symbol":"star"},"mode":"markers+text","name":"RDCs","text":["RDC 0\u003cbr\u003eNew South Wales\u003cbr\u003e(Rural)","RDC 1\u003cbr\u003eQueensland\u003cbr\u003e(Rural)","RDC 2\u003cbr\u003eWestern Australia\u003cbr\u003e(Rural)"],"textposition":"bottom center","x":[146.76436760492308,150.18974914152543,116.0691145372093],"y":[-35.84875872633846,-24.91658390432203,-31.329330289302327],"type":"scatter"},{"hovertemplate":"Transfer route\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"red","dash":"dash","width":2},"mode":"lines","name":"Transfer to RDC 0","showlegend":false,"x":[151.1250996,146.76436760492308],"y":[-29.79165152,-35.84875872633846],"type":"scatter"},{"hovertemplate":"Transfer route\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"red","dash":"dash","width":2},"mode":"lines","name":"Transfer to RDC 1","showlegend":false,"x":[151.1250996,150.18974914152543],"y":[-29.79165152,-24.91658390432203],"type":"scatter"},{"hovertemplate":"Transfer route\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"red","dash":"dash","width":2},"mode":"lines","name":"Transfer to RDC 2","showlegend":false,"x":[151.1250996,116.0691145372093],"y":[-29.79165152,-31.329330289302327],"type":"scatter"},{"hovertemplate":"%{text}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"rgb(228,26,28)","line":{"color":"white","width":1},"opacity":0.7,"size":[4.0,4.0,9.91859602,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,7.80118054582022,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.8165445,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.393268,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,13.886756383595198,4.0,4.0,4.0,4.0,4.293437643927501,4.0,4.0,4.033082039789499,5.0343033,4.0,4.341317,4.0,4.0,4.0,4.7544884000000005,4.0,4.0,4.0,4.0,4.0,4.0,4.0,15.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.3329855,4.0,4.0,5.64111639276022,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,10.032752866700001,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,15.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,15.0,7.734414749850301,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,15.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,9.211938752623501,4.0,4.0,4.0,4.0,4.0,4.0,9.865438908696,4.0,5.4702682667,4.0,4.0,8.9825162344068,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,5.492947004138,4.0,6.4797462096842,4.0,4.0,4.0,5.3971232,8.2941340295789,4.0,4.0,4.0,5.08302881,4.0,6.25820957,6.568481420000001,4.0,4.0,4.0,4.2229463,4.0,4.0,4.0,4.0,4.0,4.0,4.0,9.9121989,4.0,4.28654046265492,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,6.2928692,5.668251804138,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4. ...
# 🗺️ Creating network map for K=4 scenario...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f0950b9d-db1f-4e90-9099-4d0ba8e76f2d" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f0950b9d-db1f-4e90-9099-4d0ba8e76f2d")) {                    Plotly.newPlot(                        "f0950b9d-db1f-4e90-9099-4d0ba8e76f2d",                        [{"hovertemplate":"Original DC (NSW)\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"red","line":{"color":"white","width":3},"size":25,"symbol":"diamond"},"mode":"markers+text","name":"Original DC","text":["Original DC\u003cbr\u003eNSW"],"textposition":"top center","x":[151.1250996],"y":[-29.79165152],"type":"scatter"},{"hovertemplate":"%{text}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"blue","line":{"color":"white","width":2},"size":20,"symbol":"star"},"mode":"markers+text","name":"RDCs","text":["RDC 0\u003cbr\u003eVictoria\u003cbr\u003e(Rural)","RDC 1\u003cbr\u003eWestern Australia\u003cbr\u003e(Rural)","RDC 2\u003cbr\u003eNew South Wales\u003cbr\u003e(Rural)","RDC 3\u003cbr\u003eQueensland\u003cbr\u003e(Rural)"],"textposition":"bottom center","x":[144.26405402536585,116.0691145372093,151.79490297684728,143.78038545142857],"y":[-37.21731178439024,-31.329330289302327,-31.081008352167487,-18.628853585142856],"type":"scatter"},{"hovertemplate":"Transfer route\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"red","dash":"dash","width":2},"mode":"lines","name":"Transfer to RDC 0","showlegend":false,"x":[151.1250996,144.26405402536585],"y":[-29.79165152,-37.21731178439024],"type":"scatter"},{"hovertemplate":"Transfer route\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"red","dash":"dash","width":2},"mode":"lines","name":"Transfer to RDC 1","showlegend":false,"x":[151.1250996,116.0691145372093],"y":[-29.79165152,-31.329330289302327],"type":"scatter"},{"hovertemplate":"Transfer route\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"red","dash":"dash","width":2},"mode":"lines","name":"Transfer to RDC 2","showlegend":false,"x":[151.1250996,151.79490297684728],"y":[-29.79165152,-31.081008352167487],"type":"scatter"},{"hovertemplate":"Transfer route\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"red","dash":"dash","width":2},"mode":"lines","name":"Transfer to RDC 3","showlegend":false,"x":[151.1250996,143.78038545142857],"y":[-29.79165152,-18.628853585142856],"type":"scatter"},{"hovertemplate":"%{text}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"rgb(228,26,28)","line":{"color":"white","width":1},"opacity":0.7,"size":[4.0,9.91859602,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.7544884000000005,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.3329855,4.0,4.0,5.64111639276022,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,10.032752866700001,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,15.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,15.0,7.734414749850301,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,15.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,9.211938752623501,4.0,4.0,4.0,4.0,4.0,4.0,9.865438908696,4.0,5.4702682667,4.0,4.0,8.9825162344068,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,5.492947004138,4.0,6.4797462096842,4.0,4.0,4.0,5.3971232,8.2941340295789,4.0,4.0,4.0,5.08302881,4.0,6.25820957,6.568481420000001,4.0,4.0,4.0,4.2229463,4.0,4.0,4.0,4.0,4.0,4.0,4.0,9.9121989,4.0,4.28654046265492,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,6.2928692,5.668251804138,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.181470414138,4.1932544937169,4.0,4.0,4.50111401011]},"mode":"markers","name":"RDC 0 Zone (205 locations)","showlegend":true,"text":["\u003cb\u003e3002BR\u003c\u002fb\u003e\u00 ...
# 🗺️ Creating network map for K=5 scenario...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="28cd654d-b54f-4b70-8ef3-54cf39bf9c0b" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("28cd654d-b54f-4b70-8ef3-54cf39bf9c0b")) {                    Plotly.newPlot(                        "28cd654d-b54f-4b70-8ef3-54cf39bf9c0b",                        [{"hovertemplate":"Original DC (NSW)\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"red","line":{"color":"white","width":3},"size":25,"symbol":"diamond"},"mode":"markers+text","name":"Original DC","text":["Original DC\u003cbr\u003eNSW"],"textposition":"top center","x":[151.1250996],"y":[-29.79165152],"type":"scatter"},{"hovertemplate":"%{text}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"blue","line":{"color":"white","width":2},"size":20,"symbol":"star"},"mode":"markers+text","name":"RDCs","text":["RDC 0\u003cbr\u003eNew South Wales\u003cbr\u003e(Urban)","RDC 1\u003cbr\u003eQueensland\u003cbr\u003e(Rural)","RDC 2\u003cbr\u003eWestern Australia\u003cbr\u003e(Rural)","RDC 3\u003cbr\u003eVictoria\u003cbr\u003e(Rural)","RDC 4\u003cbr\u003eQueensland\u003cbr\u003e(Urban)"],"textposition":"bottom center","x":[150.7100443405797,142.4102441448276,116.0691145372093,143.894046556383,152.7368854375],"y":[-33.688393632826084,-17.616528913103448,-31.329330289302327,-37.406195025159576,-27.258649570795455],"type":"scatter"},{"hovertemplate":"Transfer route\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"red","dash":"dash","width":2},"mode":"lines","name":"Transfer to RDC 0","showlegend":false,"x":[151.1250996,150.7100443405797],"y":[-29.79165152,-33.688393632826084],"type":"scatter"},{"hovertemplate":"Transfer route\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"red","dash":"dash","width":2},"mode":"lines","name":"Transfer to RDC 1","showlegend":false,"x":[151.1250996,142.4102441448276],"y":[-29.79165152,-17.616528913103448],"type":"scatter"},{"hovertemplate":"Transfer route\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"red","dash":"dash","width":2},"mode":"lines","name":"Transfer to RDC 2","showlegend":false,"x":[151.1250996,116.0691145372093],"y":[-29.79165152,-31.329330289302327],"type":"scatter"},{"hovertemplate":"Transfer route\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"red","dash":"dash","width":2},"mode":"lines","name":"Transfer to RDC 3","showlegend":false,"x":[151.1250996,143.894046556383],"y":[-29.79165152,-37.406195025159576],"type":"scatter"},{"hovertemplate":"Transfer route\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"red","dash":"dash","width":2},"mode":"lines","name":"Transfer to RDC 4","showlegend":false,"x":[151.1250996,152.7368854375],"y":[-29.79165152,-27.258649570795455],"type":"scatter"},{"hovertemplate":"%{text}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"rgb(228,26,28)","line":{"color":"white","width":1},"opacity":0.7,"size":[4.0,4.0,9.91859602,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,7.80118054582022,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.8165445,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.393268,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,13.886756383595198,4.0,4.0,4.0,4.0,4.293437643927501,4.0,4.0,4.033082039789499,5.0343033,4.0,4.341317,4.0,4.0,4.0,4.7544884000000005,4.0,4.0,4.0,4.0,4.0,4.0,4.0,15.0,4.0,4.0,4.0]},"mode":"markers","name":"RDC 0 Zone (138 locations)","showlegend":true,"text":["\u003cb\u003e3001BR\u003c\u002fb\u003e\u003cbr\u003eRDC: 0 (New South Wales)\u003cbr\u003eKG: 2,360","\u003cb\u003e300 ...
# 🗺️ Creating network map for K=6 scenario...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f86f1d6c-4e26-4622-aa4b-6c3b5efeedc2" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f86f1d6c-4e26-4622-aa4b-6c3b5efeedc2")) {                    Plotly.newPlot(                        "f86f1d6c-4e26-4622-aa4b-6c3b5efeedc2",                        [{"hovertemplate":"Original DC (NSW)\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"red","line":{"color":"white","width":3},"size":25,"symbol":"diamond"},"mode":"markers+text","name":"Original DC","text":["Original DC\u003cbr\u003eNSW"],"textposition":"top center","x":[151.1250996],"y":[-29.79165152],"type":"scatter"},{"hovertemplate":"%{text}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"blue","line":{"color":"white","width":2},"size":20,"symbol":"star"},"mode":"markers+text","name":"RDCs","text":["RDC 0\u003cbr\u003eNew South Wales\u003cbr\u003e(Urban)","RDC 1\u003cbr\u003eWestern Australia\u003cbr\u003e(Rural)","RDC 2\u003cbr\u003eQueensland\u003cbr\u003e(Rural)","RDC 3\u003cbr\u003eQueensland\u003cbr\u003e(Urban)","RDC 4\u003cbr\u003eSouth Australia\u003cbr\u003e(Rural)","RDC 5\u003cbr\u003eVictoria\u003cbr\u003e(Urban)"],"textposition":"bottom center","x":[150.78448194558823,116.0691145372093,142.4102441448276,152.7368854375,138.8684970948718,145.21527112781456],"y":[-33.6792490642647,-31.329330289302327,-17.616528913103448,-27.258649570795455,-34.761420522820515,-38.048276244569536],"type":"scatter"},{"hovertemplate":"Transfer route\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"red","dash":"dash","width":2},"mode":"lines","name":"Transfer to RDC 0","showlegend":false,"x":[151.1250996,150.78448194558823],"y":[-29.79165152,-33.6792490642647],"type":"scatter"},{"hovertemplate":"Transfer route\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"red","dash":"dash","width":2},"mode":"lines","name":"Transfer to RDC 1","showlegend":false,"x":[151.1250996,116.0691145372093],"y":[-29.79165152,-31.329330289302327],"type":"scatter"},{"hovertemplate":"Transfer route\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"red","dash":"dash","width":2},"mode":"lines","name":"Transfer to RDC 2","showlegend":false,"x":[151.1250996,142.4102441448276],"y":[-29.79165152,-17.616528913103448],"type":"scatter"},{"hovertemplate":"Transfer route\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"red","dash":"dash","width":2},"mode":"lines","name":"Transfer to RDC 3","showlegend":false,"x":[151.1250996,152.7368854375],"y":[-29.79165152,-27.258649570795455],"type":"scatter"},{"hovertemplate":"Transfer route\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"red","dash":"dash","width":2},"mode":"lines","name":"Transfer to RDC 4","showlegend":false,"x":[151.1250996,138.8684970948718],"y":[-29.79165152,-34.761420522820515],"type":"scatter"},{"hovertemplate":"Transfer route\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"red","dash":"dash","width":2},"mode":"lines","name":"Transfer to RDC 5","showlegend":false,"x":[151.1250996,145.21527112781456],"y":[-29.79165152,-38.048276244569536],"type":"scatter"},{"hovertemplate":"%{text}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"rgb(228,26,28)","line":{"color":"white","width":1},"opacity":0.7,"size":[4.0,4.0,9.91859602,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,7.80118054582022,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.8165445,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.393268,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,13.8867563835 ...
# 🗺️ Creating network map for K=7 scenario...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="194ce1b6-2fed-467c-8d36-482af221e34e" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("194ce1b6-2fed-467c-8d36-482af221e34e")) {                    Plotly.newPlot(                        "194ce1b6-2fed-467c-8d36-482af221e34e",                        [{"hovertemplate":"Original DC (NSW)\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"red","line":{"color":"white","width":3},"size":25,"symbol":"diamond"},"mode":"markers+text","name":"Original DC","text":["Original DC\u003cbr\u003eNSW"],"textposition":"top center","x":[151.1250996],"y":[-29.79165152],"type":"scatter"},{"hovertemplate":"%{text}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"blue","line":{"color":"white","width":2},"size":20,"symbol":"star"},"mode":"markers+text","name":"RDCs","text":["RDC 0\u003cbr\u003eVictoria\u003cbr\u003e(Urban)","RDC 1\u003cbr\u003eWestern Australia\u003cbr\u003e(Urban)","RDC 2\u003cbr\u003eNew South Wales\u003cbr\u003e(Urban)","RDC 3\u003cbr\u003eQueensland\u003cbr\u003e(Rural)","RDC 4\u003cbr\u003eWestern Australia\u003cbr\u003e(Rural)","RDC 5\u003cbr\u003eQueensland\u003cbr\u003e(Urban)","RDC 6\u003cbr\u003eSouth Australia\u003cbr\u003e(Rural)"],"textposition":"bottom center","x":[145.21527112781456,115.9662084775,150.78448194558823,146.09929530869564,127.00897451,152.7895752586207,138.8684970948718],"y":[-38.048276244569536,-32.132287636,-33.6792490642647,-19.35941058608696,-15.100743799999996,-27.30156685321839,-34.761420522820515],"type":"scatter"},{"hovertemplate":"Transfer route\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"red","dash":"dash","width":2},"mode":"lines","name":"Transfer to RDC 0","showlegend":false,"x":[151.1250996,145.21527112781456],"y":[-29.79165152,-38.048276244569536],"type":"scatter"},{"hovertemplate":"Transfer route\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"red","dash":"dash","width":2},"mode":"lines","name":"Transfer to RDC 1","showlegend":false,"x":[151.1250996,115.9662084775],"y":[-29.79165152,-32.132287636],"type":"scatter"},{"hovertemplate":"Transfer route\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"red","dash":"dash","width":2},"mode":"lines","name":"Transfer to RDC 2","showlegend":false,"x":[151.1250996,150.78448194558823],"y":[-29.79165152,-33.6792490642647],"type":"scatter"},{"hovertemplate":"Transfer route\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"red","dash":"dash","width":2},"mode":"lines","name":"Transfer to RDC 3","showlegend":false,"x":[151.1250996,146.09929530869564],"y":[-29.79165152,-19.35941058608696],"type":"scatter"},{"hovertemplate":"Transfer route\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"red","dash":"dash","width":2},"mode":"lines","name":"Transfer to RDC 4","showlegend":false,"x":[151.1250996,127.00897451],"y":[-29.79165152,-15.100743799999996],"type":"scatter"},{"hovertemplate":"Transfer route\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"red","dash":"dash","width":2},"mode":"lines","name":"Transfer to RDC 5","showlegend":false,"x":[151.1250996,152.7895752586207],"y":[-29.79165152,-27.30156685321839],"type":"scatter"},{"hovertemplate":"Transfer route\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"red","dash":"dash","width":2},"mode":"lines","name":"Transfer to RDC 6","showlegend":false,"x":[151.1250996,138.8684970948718],"y":[-29.79165152,-34.761420522820515],"type":"scatter"},{"hovertemplate":"%{text}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"rgb(228,26,28)","line":{"color":"white","width":1},"opacity":0.7,"size":[4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,4.0,5.6411163927602 ...
# 🗺️ Creating network map for K=8 scenario...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2fee5b87-e142-4c3d-bf19-371aac339c7a" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2fee5b87-e142-4c3d-bf19-371aac339c7a")) {                    Plotly.newPlot(                        "2fee5b87-e142-4c3d-bf19-371aac339c7a",                        [{"hovertemplate":"Original DC (NSW)\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"red","line":{"color":"white","width":3},"size":25,"symbol":"diamond"},"mode":"markers+text","name":"Original DC","text":["Original DC\u003cbr\u003eNSW"],"textposition":"top center","x":[151.1250996],"y":[-29.79165152],"type":"scatter"},{"hovertemplate":"%{text}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"blue","line":{"color":"white","width":2},"size":20,"symbol":"star"},"mode":"markers+text","name":"RDCs","text":["RDC 0\u003cbr\u003eNew South Wales\u003cbr\u003e(Urban)","RDC 1\u003cbr\u003eWestern Australia\u003cbr\u003e(Urban)","RDC 2\u003cbr\u003eQueensland\u003cbr\u003e(Urban)","RDC 3\u003cbr\u003eVictoria\u003cbr\u003e(Urban)","RDC 4\u003cbr\u003eQueensland\u003cbr\u003e(Rural)","RDC 5\u003cbr\u003eWestern Australia\u003cbr\u003e(Rural)","RDC 6\u003cbr\u003eSouth Australia\u003cbr\u003e(Rural)","RDC 7\u003cbr\u003eSouth Australia\u003cbr\u003e(Rural)"],"textposition":"bottom center","x":[150.78448194558823,115.9662084775,152.7895752586207,145.21527112781456,146.09929530869564,117.44119533333333,138.8684970948718,131.10945130000002],"y":[-33.6792490642647,-32.132287636,-27.30156685321839,-38.048276244569536,-19.35941058608696,-20.623232333333334,-34.761420522820515,-12.733963],"type":"scatter"},{"hovertemplate":"Transfer route\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"red","dash":"dash","width":2},"mode":"lines","name":"Transfer to RDC 0","showlegend":false,"x":[151.1250996,150.78448194558823],"y":[-29.79165152,-33.6792490642647],"type":"scatter"},{"hovertemplate":"Transfer route\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"red","dash":"dash","width":2},"mode":"lines","name":"Transfer to RDC 1","showlegend":false,"x":[151.1250996,115.9662084775],"y":[-29.79165152,-32.132287636],"type":"scatter"},{"hovertemplate":"Transfer route\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"red","dash":"dash","width":2},"mode":"lines","name":"Transfer to RDC 2","showlegend":false,"x":[151.1250996,152.7895752586207],"y":[-29.79165152,-27.30156685321839],"type":"scatter"},{"hovertemplate":"Transfer route\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"red","dash":"dash","width":2},"mode":"lines","name":"Transfer to RDC 3","showlegend":false,"x":[151.1250996,145.21527112781456],"y":[-29.79165152,-38.048276244569536],"type":"scatter"},{"hovertemplate":"Transfer route\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"red","dash":"dash","width":2},"mode":"lines","name":"Transfer to RDC 4","showlegend":false,"x":[151.1250996,146.09929530869564],"y":[-29.79165152,-19.35941058608696],"type":"scatter"},{"hovertemplate":"Transfer route\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"red","dash":"dash","width":2},"mode":"lines","name":"Transfer to RDC 5","showlegend":false,"x":[151.1250996,117.44119533333333],"y":[-29.79165152,-20.623232333333334],"type":"scatter"},{"hovertemplate":"Transfer route\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"red","dash":"dash","width":2},"mode":"lines","name":"Transfer to RDC 6","showlegend":false,"x":[151.1250996,138.8684970948718],"y":[-29.79165152,-34.761420522820515],"type":"scatter"},{"hovertemplate":"Transfer route\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"red","dash":"dash","width":2},"mode":"lines","name":"Transfer to RDC 7","showlegend":false,"x":[151 ...
